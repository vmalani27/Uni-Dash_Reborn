# %%
import pandas as pd

# %%
df_path = "D:\\vanshmalanidata\\Documents\\GitHub\\Uni-Dash_Reborn\\data"
df = pd.read_csv(df_path + "\\23DCS023_all_emails.csv")
# df=pd.read_csv("labeled_dataset.csv")

# %%
import re
import pandas as pd

# ---------------------------------------------------
# 1. REMOVE CHARUSAT DISCLAIMER
# ---------------------------------------------------
def remove_charusat_disclaimer(text):
    # Remove only the long legal footer, not message body
    pattern = r"(?is)disclaimer[:].*"
    return re.sub(pattern, "", str(text)).strip()


# ---------------------------------------------------
# 2. CLEAN TEXT
# ---------------------------------------------------
def clean_text(text):
    text = str(text)

    text = remove_charusat_disclaimer(text)

    # Remove generic signatures (keep forwarded content intact)
    text = re.sub(
        r"(?is)(thanks[,.]?$|regards[,.]?$|warm regards[,.]?$|best wishes[,.]?$)",
        "",
        text
    )

    # Remove long signature blocks if they are at the end (200 chars max)
    text = re.sub(r"(?is)(thanks|regards)[\s\S]{0,200}$", "", text)

    # Remove URLs only
    text = re.sub(r"http\S+|www\.\S+", "", text)

    # Collapse extra whitespace
    text = re.sub(r"\s+", " ", text).strip()

    return text.lower()


# ---------------------------------------------------
# 3. EMAIL + DOMAIN EXTRACTION
# ---------------------------------------------------
def extract_email(text):
    match = re.search(r'[\w\.-]+@[\w\.-]+', str(text))
    return match.group(0).lower() if match else ""

def extract_domain(email):
    return email.split('@')[-1] if "@" in email else ""


# ---------------------------------------------------
# 4. FLAGS
# ---------------------------------------------------
def contains_submit_word(text):
    return bool(re.search(r"\b(submit|upload|last date|due|fill)\b", text))

def contains_exam_word(text):
    return bool(re.search(r"\b(exam|test|cie|hall ticket|seating)\b", text))

def contains_event_word(text):
    return bool(re.search(r"\b(hackathon|event|bootcamp|seminar|workshop|competition)\b", text))

def contains_form_link(text):
    return bool(re.search(r"(docs\.google\.com/forms|forms\.gle)", text))


# ---------------------------------------------------
# 5. DEADLINE EXTRACTION
# ---------------------------------------------------
def extract_deadline(text):
    pattern = r"(due|deadline|submit by|last date)[:\- ]*(\d{1,2}[/-]\d{1,2}[/-]\d{2,4}|\d{1,2}\s+\w+\s+\d{4})"
    m = re.search(pattern, text, re.IGNORECASE)
    return m.group(2) if m else ""


# ---------------------------------------------------
# 6. PIPELINE
# ---------------------------------------------------
cols_to_drop = ["Unnamed: 0", "id", "threadId", "labelIds", "snippet"]
df = df.drop(columns=[c for c in cols_to_drop if c in df.columns], errors="ignore")

df["raw_text"] = df["subject"].astype(str) + " " + df["content"].astype(str)
df["clean_text"] = df["raw_text"].apply(clean_text)

df["sender_email"] = df["from"].apply(extract_email)
df["sender_domain"] = df["sender_email"].apply(extract_domain)

df["deadline_date"] = ""
    
df["label_source"] = ""
df["label_topic"] = ""
df["label_urgency"] = ""


# ---------------------------------------------------
# 7. FILTERING RULES
# ---------------------------------------------------

# Delete ONLY pure system messages (not real emails)
df = df[~df["from"].str.contains(r"^no-reply@classroom\.google\.com$", na=False, case=False)]

# Keep short tiny urgent mails
df = df[df["clean_text"].str.len() > 5].reset_index(drop=True)

df.head()
# Out:
#                                                 from  \
# 0  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....
# 1  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....
# 2             NPTEL <onlinecourses@nptel.iitm.ac.in>
# 3  "Parth Goel (Classroom)" <no-reply@classroom.g...
# 4                   Team at Read <support@e.read.ai>
#
#                                              subject  \
# 0  Request for Email Data Contribution – Research...
# 1  Re: Request for Email Data Contribution – Rese...
# 2  NPTEL Newsletter: IIT Madras CODE Certificate ...
# 3  New announcement: "Dear Students,\r\n\r\nYou a...
# 4          Exclusive Education Pricing Just for You!
#
#                         date  \
# 0  2025-06-25 20:36:16+05:30
# 1  2025-06-25 20:31:44+05:30
# 2  2025-06-25 15:52:01+05:30
# 3  2025-06-25 04:27:54-07:00
# 4  2025-06-25 09:33:48+00:00
#
#                                              content  \
# 0  Dear Student\r\n\r\nThank you so much for your...
# 1  I hope you're doing well.\r\n\r\nThis is a fin...
# 2  <https://code.iitm.ac.in/foundations-to-ml>\r\...
# 3  \r\nNotification settings  \r\n<https://accoun...
# 4  Read AI for $5 Per Month\r\nHi 23DCS023 , as a...
#
#                                             raw_text  \
# 0  Request for Email Data Contribution – Research...
# 1  Re: Request for Email Data Contribution – Rese...
# 2  NPTEL Newsletter: IIT Madras CODE Certificate ...
# 3  New announcement: "Dear Students,\r\n\r\nYou a...
# 4  Exclusive Education Pricing Just for You! Read...
#
#                                           clean_text  \
# 0  request for email data contribution – research...
# 1  re: request for email data contribution – rese...
# 2  nptel newsletter: iit madras code certificate ...
# 3  new announcement: "dear students, you are requ...
# 4  exclusive education pricing just for you! read...
#
#                      sender_email         sender_domain deadline_date  \
# 0        23dcs023@charusat.edu.in       charusat.edu.in
# 1        23dcs023@charusat.edu.in       charusat.edu.in
# 2  onlinecourses@nptel.iitm.ac.in      nptel.iitm.ac.in
# 3   no-reply@classroom.google.com  classroom.google.com
# 4               support@e.read.ai             e.read.ai
#
#   label_source label_topic label_urgency
# 0
# 1
# 2
# 3
# 4

# %%
# Remove emails from classroom.google.com domain
df = df[~df["sender_domain"].str.contains(r"classroom\.google\.com$", na=False, case=False)]

# %%
df.columns
# Out:
# Index(['from', 'subject', 'date', 'content', 'raw_text', 'clean_text',
#        'sender_email', 'sender_domain', 'deadline_date', 'label_source',
#        'label_topic', 'label_urgency'],
#       dtype='object')

# %%
# Find rows where clean_text contains the keyword 'fees' (case-insensitive) and display them
fees_rows = df[df['clean_text'].str.contains('fees', case=False, na=False)]
for i, text in enumerate(fees_rows["clean_text"].head(20), 1):
    print(f"\n--- ROW {i} ---\n{text}\n")
# Out:
# --- ROW 1 ---
# semester 5 fee payment schedule - b.tech programme dear students, this is an important reminder regarding the fee payment for the upcoming semester 5 of the b.tech programme. kindly ensure that the fees are paid as per the schedule to avoid any late fines or penalties. please refer to the attached notice for detailed information on the payment process and deadlines. for any queries or clarifications, feel free to reach out to your counsellor or semester coordinator. -- with
#
#
# --- ROW 2 ---
# nptel newsletter: june 2025: vol 6: week 2! nptel new < ­ *soar into the future with aerospace engineering! 🛩️* delve into mysteries of flight and space with aerospace engineering courses! from aircraft dynamics to rocket propulsion, dive into the science that powers modern aviation and space exploration. | join now to be future-ready and be part of the next leap in technology! 💡 *know more * < < code programs *digital transformation - fundamentals : cohort 2* check out the feedback from the first batch students for this course delivered by ex-chief digital officer of ashok leyland. *enroll in this course today to avail at a discounted early bird fees!* < < ­ *construction technology and management : cohort 4* check out more about this most sought after course by a group of expert iit madras professors. learn about the latest cutting edge construction technology and also management. *enroll today for early bird discounted fees!* < < ­ iit madras school connect program *schools can partner with us; introduce your students to future careers* these introductory courses aim to foster career awareness and provide students with a blend of theoretical understanding and hands-on application. these hands-on courses are meticulously designed with a strong emphasis on career guidance, and are taught by professors from iits and other leading indian institutions. we are pleased to share that our initiative to empower students has reached a significant milestone, having partnered with over 2,200+ schools, positively impacting approximately 50,000 students through our 8-week certification programs. | our upcoming batch kicks off on august 4, 2025; students from classes 10, 11 and 12 may register for a fee of rs. 500/- per course. | we look forward to collaborating with even more schools, giving a wider range of students the chance to gain valuable skills in these transformative fields. registration for the upcoming batch is from june 16 to july 25, 2025. | schools interested in partnering with us can register through our website: * < ­ *nptel+ workshops:* *1. career development : grow your team* *register now* < - * *rs. 250 onwards* - *2. career development : grow your self* *register now* < - * *rs. 250 onwards* - *3. career development : grow your ai skills* *register now* < - * *rs. 250 onwards* - 4. karmic design thinking for human-centered products and services *registrations open* < - * *rs. 1,950* *last day to register: june 26, 2025* 5. hands-on programming sessions for quantum computers *registrations open* < - * *rs. 1,000* *last day to register: **june 10, 2025* 6. introduction to hydrodynamic stability *registrations open* < - * *rs. 1,499 onwards* *last day to register: june 12, 2025* 7. 21st century food tech innovations for nutrition and health security – 2 *registrations open* < - * *rs. 500 onwards* *last day to register: july 2, 2025* 8. high-rise structures *registrations open* < - * *rs. 1000* *last day to register: july 9, 2025* 9. career development : grow your communication *registrations open* < - * *rs. 250 onwards* *last day to register: july 15, 2025* ­ follow us: < ­ < ­ < ­ < ­ *nptel administrator,* ic & sr, 3rd floor iit madras, chennai - 600036 thanks and regards, nptel team. -- to unsubscribe from this group and stop receiving emails from it: log in to google groups and click on my groups seen in the left navigation pane. you will see the list of your groups. choose the group "nptel newsletter" click the leave group icon on the right side to leave the group or you can choose the "no email" option under subscription to stop receiving these emails. to unsubscribe from this group and stop receiving emails from it, send an email to newsletter-announce+unsubscribe@nptel.iitm.ac.in.
#
#
# --- ROW 3 ---
# weekly kickoff | mon, may 26th | read.ai need a recap? review meeting notes, personalized coaching, meeting trends, and more. 23dcs023's weekly recap 🗓 mon, may 26th through sun, june 1st in the recent meetings, sagar khatri provided an overview of arrays, explaining the distinctions between one-dimensional, two-dimensional, and three-dimensional arrays, along with their shapes. he also discussed an internship program for students, detailing the registration process, fees, and the types of internships available, including both paid and free options... more for you ➔ ( ) meeting notes catch up on notable reports from last week ds & ml may internship 2025 may 30, 2025 @ 11:28am (absent) ✅️ 2 action items 🤔️ 2 questions sagar khatri outlined the task responsibilities for the group of 44 students during his absence due to travel, encouraging them to ask questions verba... review report ➔ ( ) view all meeting reports ( ) coming up this week you have 10 calendar events and read is joining 6. add read to more meetings ( ). you have 30 hours of focus time. carve out more with read smart scheduler ( ). want to skip the back-and-forth of meeting scheduling? try out your read smart scheduler link: cal.read.ai/23dcs023-l1ey4 ( ) need help? visit the support center ( ) or contact us ( support@read.ai ). team at read 999 3rd ave, suite 3300, seattle, wa 98104 unsubscribe ( ) • email preferences ( )
#
#
# --- ROW 4 ---
# fwd: proposal for students to participate in the unteched japan international education study tour: july 2025proposal for students to participate in the unteched japan international education study tour: july 2025 regards, radhika h. patel, assistant professor, department of information technology, devang patel institute of advance technology and research (depstar), charusat, changa ---------- forwarded message --------- from: provost charusat <provost@charusat.ac.in> date: wed, 28 may 2025, 7:41 pm subject: fwd: proposal for students to participate in the unteched japan international education study tour: july 2025proposal for students to participate in the unteched japan international education study tour: july 2025 to: teaching staff <teachingstaff@charusat.ac.in>, registrar charusat < registrar@charusat.ac.in>, deputy registrar (academics & exams) charusat < dy.registrar.ace@charusat.ac.in> *dr r.v. upadhyay,* *provost (vice-chancellor),* charotar university of science and technology (charusat) off. nadiad - petlad highway, changa-388421, gujarat, india c: +91 9427215242 | ph: +91 2697 265015 | e: provost@charusat.ac.in <registrar@charusat.ac.in> | w: ---------- forwarded message --------- from: manshi verma <communications@unteched.in> date: wed, 28 may 2025, 18:12 subject: proposal for students to participate in the unteched japan international education study tour: july 2025proposal for students to participate in the unteched japan international education study tour: july 2025 to: provost@charusat.ac.in <provost@charusat.ac.in> dear dr. rv upadhyay greetings from unteched! we are thrilled to present an extraordinary opportunity for your students to join the *unteched international education study tour: japan 2025*, titled *"go abroad, unlock your potential."* hosted *in partnership with fpt academy japan*, this immersive *one-week program* combines academic excellence with cultural exploration, offering a transformative experience for participants. *program overview:* *host country: tokyo, japan* *host university partner: fpt academy japan* *duration: 14 july – 20 july, 2025 (7 days / 6 nights)* participants will gain hands-on exposure through academic sessions, workshops, and cultural immersion activities. this program is specifically designed to broaden global perspectives, enhance professional skills, and provide an unforgettable learning adventure. *program highlights:* *1. academic sessions: *led by top experts, students will delve into trending topics such as: - ai application in business - digital transformation - cybersecurity in business - diversity, equity, and inclusion *2. field trip at a global company (all in english)* - welcome ceremony & company tour - seminar with experts - skill-up workshop - groupwork *3. experience japanese culture* - calligraphy culture class with japanese teacher - unique insights into japanese lifestyle - immersive cultural activities and sightseeing *program cost:* *program fee: 1100 usd (approx. inr 93,500)* (note: payment to be paid in international account, additional 18% gst applicable for payments to an indian account.) *inclusions:* - 6 nights accommodation in dormitories (shared basis) - local airport transfers (group pick-up & drop) - local transport for program-related visits - orientation and in-program activity fees (including transportation & entrance tickets) - study materials and printing fees - an english-speaking buddy to assist students during program activities - certificate of participation from fpt japan *exclusions:* flights, visa fee, meals, travel & health insurance, personal expenses ***unteched will assist students with flight bookings and visa lodgement.* *registration link: < *encourage your students to register early to secure their spots.* this program is an excellent way for students to enhance their academic profiles, gain global exposure, and immerse themselves in japan's rich culture. we look forward to collaborating with you to make this initiati ...
#
#
# --- ROW 5 ---
# fwd: proposal for students to participate in the unteched japan international education study tour: july 2025proposal for students to participate in the unteched japan international education study tour: july 2025 ---------- forwarded message --------- from: provost charusat <provost@charusat.ac.in> date: wed, may 28, 2025, 7:41 pm subject: fwd: proposal for students to participate in the unteched japan international education study tour: july 2025proposal for students to participate in the unteched japan international education study tour: july 2025 to: teaching staff <teachingstaff@charusat.ac.in>, registrar charusat < registrar@charusat.ac.in>, deputy registrar (academics & exams) charusat < dy.registrar.ace@charusat.ac.in> *dr r.v. upadhyay,* *provost (vice-chancellor),* charotar university of science and technology (charusat) off. nadiad - petlad highway, changa-388421, gujarat, india c: +91 9427215242 | ph: +91 2697 265015 | e: provost@charusat.ac.in <registrar@charusat.ac.in> | w: ---------- forwarded message --------- from: manshi verma <communications@unteched.in> date: wed, 28 may 2025, 18:12 subject: proposal for students to participate in the unteched japan international education study tour: july 2025proposal for students to participate in the unteched japan international education study tour: july 2025 to: provost@charusat.ac.in <provost@charusat.ac.in> dear dr. rv upadhyay greetings from unteched! we are thrilled to present an extraordinary opportunity for your students to join the *unteched international education study tour: japan 2025*, titled *"go abroad, unlock your potential."* hosted *in partnership with fpt academy japan*, this immersive *one-week program* combines academic excellence with cultural exploration, offering a transformative experience for participants. *program overview:* *host country: tokyo, japan* *host university partner: fpt academy japan* *duration: 14 july – 20 july, 2025 (7 days / 6 nights)* participants will gain hands-on exposure through academic sessions, workshops, and cultural immersion activities. this program is specifically designed to broaden global perspectives, enhance professional skills, and provide an unforgettable learning adventure. *program highlights:* *1. academic sessions: *led by top experts, students will delve into trending topics such as: - ai application in business - digital transformation - cybersecurity in business - diversity, equity, and inclusion *2. field trip at a global company (all in english)* - welcome ceremony & company tour - seminar with experts - skill-up workshop - groupwork *3. experience japanese culture* - calligraphy culture class with japanese teacher - unique insights into japanese lifestyle - immersive cultural activities and sightseeing *program cost:* *program fee: 1100 usd (approx. inr 93,500)* (note: payment to be paid in international account, additional 18% gst applicable for payments to an indian account.) *inclusions:* - 6 nights accommodation in dormitories (shared basis) - local airport transfers (group pick-up & drop) - local transport for program-related visits - orientation and in-program activity fees (including transportation & entrance tickets) - study materials and printing fees - an english-speaking buddy to assist students during program activities - certificate of participation from fpt japan *exclusions:* flights, visa fee, meals, travel & health insurance, personal expenses ***unteched will assist students with flight bookings and visa lodgement.* *registration link: < *encourage your students to register early to secure their spots.* this program is an excellent way for students to enhance their academic profiles, gain global exposure, and immerse themselves in japan's rich culture. we look forward to collaborating with you to make this initiative a success. for any queries or assistance, please feel free to contact us. we look forward to your students joining us on this exciting journey to explore the vibrant cu ...
#
#
# --- ROW 6 ---
# fwd: proposal for students to participate in the unteched japan international education study tour: july 2025proposal for students to participate in the unteched japan international education study tour: july 2025 ---------- forwarded message --------- from: provost charusat <provost@charusat.ac.in> date: wed, may 28, 2025, 7:41 pm subject: fwd: proposal for students to participate in the unteched japan international education study tour: july 2025proposal for students to participate in the unteched japan international education study tour: july 2025 to: teaching staff <teachingstaff@charusat.ac.in>, registrar charusat < registrar@charusat.ac.in>, deputy registrar (academics & exams) charusat < dy.registrar.ace@charusat.ac.in> *dr r.v. upadhyay,* *provost (vice-chancellor),* charotar university of science and technology (charusat) off. nadiad - petlad highway, changa-388421, gujarat, india c: +91 9427215242 | ph: +91 2697 265015 | e: provost@charusat.ac.in <registrar@charusat.ac.in> | w: ---------- forwarded message --------- from: manshi verma <communications@unteched.in> date: wed, 28 may 2025, 18:12 subject: proposal for students to participate in the unteched japan international education study tour: july 2025proposal for students to participate in the unteched japan international education study tour: july 2025 to: provost@charusat.ac.in <provost@charusat.ac.in> dear dr. rv upadhyay greetings from unteched! we are thrilled to present an extraordinary opportunity for your students to join the *unteched international education study tour: japan 2025*, titled *"go abroad, unlock your potential."* hosted *in partnership with fpt academy japan*, this immersive *one-week program* combines academic excellence with cultural exploration, offering a transformative experience for participants. *program overview:* *host country: tokyo, japan* *host university partner: fpt academy japan* *duration: 14 july – 20 july, 2025 (7 days / 6 nights)* participants will gain hands-on exposure through academic sessions, workshops, and cultural immersion activities. this program is specifically designed to broaden global perspectives, enhance professional skills, and provide an unforgettable learning adventure. *program highlights:* *1. academic sessions: *led by top experts, students will delve into trending topics such as: - ai application in business - digital transformation - cybersecurity in business - diversity, equity, and inclusion *2. field trip at a global company (all in english)* - welcome ceremony & company tour - seminar with experts - skill-up workshop - groupwork *3. experience japanese culture* - calligraphy culture class with japanese teacher - unique insights into japanese lifestyle - immersive cultural activities and sightseeing *program cost:* *program fee: 1100 usd (approx. inr 93,500)* (note: payment to be paid in international account, additional 18% gst applicable for payments to an indian account.) *inclusions:* - 6 nights accommodation in dormitories (shared basis) - local airport transfers (group pick-up & drop) - local transport for program-related visits - orientation and in-program activity fees (including transportation & entrance tickets) - study materials and printing fees - an english-speaking buddy to assist students during program activities - certificate of participation from fpt japan *exclusions:* flights, visa fee, meals, travel & health insurance, personal expenses ***unteched will assist students with flight bookings and visa lodgement.* *registration link: < *encourage your students to register early to secure their spots.* this program is an excellent way for students to enhance their academic profiles, gain global exposure, and immerse themselves in japan's rich culture. we look forward to collaborating with you to make this initiative a success. for any queries or assistance, please feel free to contact us. we look forward to your students joining us on this exciting journey to explore the vibrant cu ...
#
#
# --- ROW 7 ---
# weekly kickoff | mon, may 19th | read.ai need a recap? review meeting notes, personalized coaching, meeting trends, and more. 23dcs023's weekly recap 🗓 mon, may 19th through sun, may 25th in the recent meetings, sagar khatri provided an overview of arrays, explaining the distinctions between one-dimensional, two-dimensional, and three-dimensional arrays, along with their shapes. he also discussed an internship program for students, detailing the registration process, fees, and the types of internships available, including both paid and free options... more for you ➔ ( ) meeting notes catch up on notable reports from last week ds & ml internship 30d changa college may 19, 2025 @ 4:30pm (absent) ✅️ 2 action items 🤔️ 2 questions the discussion centered on the ds & ml internship at changa college, with sagar khatri detailing his advancements in feature construction and dataset ... review report ➔ ( ) ds & ml may internship 2025 may 22, 2025 @ 11:29am (absent) ✅️ 2 action items 🤔️ 2 questions sagar khatri led a training session on power bi, emphasizing its application in data analysis and its similarities to excel, while encouraging partici... review report ➔ ( ) view all meeting reports ( ) coming up this week you have 10 calendar events and read is joining 10. add read to more meetings ( ). you have 30 hours of focus time. carve out more with read smart scheduler ( ). want to skip the back-and-forth of meeting scheduling? try out your read smart scheduler link: cal.read.ai/23dcs023-l1ey4 ( ) need help? visit the support center ( ) or contact us ( support@read.ai ). team at read 999 3rd ave, suite 3300, seattle, wa 98104 unsubscribe ( ) • email preferences ( )
#
#
# --- ROW 8 ---
# re: university theory and practical examination schedule-2024-25, even term dear students, please find attached herewith sheet for practical exam and viva locations. on thu, apr 3, 2025 at 9:39 am dipak ramoliya < dipakramoliya.ce@charusat.ac.in> wrote: > dear vraj, > > find the timetable of the practical exam. > > come and meet me for the exam. i will assist in reaching the respective > subject faculty for the exam. > > complete your exam fees payment. > ================================================== > > ---------- forwarded message --------- > from: naina parmar <nainaparmar.dcs@charusat.ac.in> > date: tue, apr 1, 2025 at 1:39 pm > subject: university theory and practical examination schedule-2024-25, > even term > to: <23dcse@charusat.edu.in> > cc: head cse depstar <hod.csds@charusat.ac.in>, ankita amaravat < > ankitaamaravat.cse@charusat.ac.in>, disha panchal < > dishapanchal.dcs@charusat.ac.in>, dipak ramoliya < > dipakramoliya.ce@charusat.ac.in> > > > dear students, > > please find attached herewith the *university* *theory and practical > examination **schedule* *for sem - 4.* > > concerned students are hereby informed to adhere to the instructions for > the university examination. > > contact the undersigned/prof. disha panchal/prof. ankita amravat for any > query/concern. > > > thanks & regards, > naina parmar, > assistant professor, > computer science & engineering department, > devang patel institute of advance technology and research (depstar) > changa-gujarat 388421 > > > -- > *dipak ramoliya** /assistant professor,* > department of computer science & engineering, depstar, > charotar university of science & technology(charusat)- changa, > email: dipakramoliya.ce@charusat.ac.in, > mo. +91 99987 71587 > > > * accredited grade “a+” by naac, goi* > --
#
#
# --- ROW 9 ---
# accenture accredited internship program - registration form i've invited you to fill out the following form: accenture accredited internship program - registration form to fill it out, visit: hi charotar university of science and technology students, krutanic solutions, accredited by accenture, is offering an exclusive scholarship discount for the first 15 students from your campus! don&#39;t miss this limited-time opportunity! use referral code: charust30 note: training fees are applicable, but the students get a 30% scholarship discount. accredited by accenture :-charotar university of science and technology training and internship act fast to secure your spot google forms: create and analyze surveys.
#
#
# --- ROW 10 ---
# re: registration fees for cloud practitioner new batch dear all now you can go to admin department to pay aws academy registration fee. please follow the instructions given in the above mail. on wed, 2 apr, 2025, 12:33 pm sanket suthar, <sanketsuthar.it@charusat.ac.in> wrote: > dear students, > > as you all know, we are starting our* new batch* for *aws-cloud > practitioner*. for the same you need to pay your registration fees *rs. > 1500(including tax) at the account section. * > > *go to the account section (admin building) *and provide this information. > > *1. your id no. :* *d21it170 (for example)* > *2. course name : aws-academy * > *3. batch name: aws-cp-2025-2026-sbs-rvp* > > *note :* give exact course & batch name in the account section. > verify both in your payment receipt before you leave account section > > once you complete your registration process you can continue your classes > held every saturday. > > starting date of academy: *23 june 2025 (saturday).* > location: 628-a lab, cspit-it, a7 building > time: 04:30 pm onwards > > dr. sanket suthar > > assistant professor > > faculty training and placement representative > > department of information technology | cspit | charusat > > accredited grade 'a+' by naac > [image: mobilephone] +91 9909147190 > [image: emailaddress] sanketsuthar.it@charusat.ac.in > <sanketsuthar.it@charusat.ac.ion> > [image: address] charotar university of science and technology > --
#
#
# --- ROW 11 ---
# registration fees for cloud practitioner new batch dear students, as you all know, we are starting our* new batch* for *aws-cloud practitioner*. for the same you need to pay your registration fees *rs. 1500(including tax) at the account section. * *go to the account section (admin building) *and provide this information. *1. your id no. :* *d21it170 (for example)* *2. course name : aws-academy * *3. batch name: aws-cp-2025-2026-sbs-rvp* *note :* give exact course & batch name in the account section. verify both in your payment receipt before you leave account section once you complete your registration process you can continue your classes held every saturday. starting date of academy: *23 june 2025 (saturday).* location: 628-a lab, cspit-it, a7 building time: 04:30 pm onwards dr. sanket suthar assistant professor faculty training and placement representative department of information technology | cspit | charusat accredited grade 'a+' by naac [image: mobilephone] +91 9909147190 [image: emailaddress] sanketsuthar.it@charusat.ac.in <sanketsuthar.it@charusat.ac.ion> [image: address] charotar university of science and technology --
#
#
# --- ROW 12 ---
# certification course on "internet of vehicles (iov): 5g and beyond autonomous and connected cars" dear students, short description of the course. *about the course :* this certification course explores both fundamental and advanced concepts of the internet of vehicles (iov) with a focus on 5g technology and its applications in autonomous and connected cars. the course aims to provide a comprehensive understanding of iov integration with modern vehicular technology, enhancing connectivity, safety, and efficiency. *course objective :* the course is focused on the professional sectors like embedded, cyber security, network analysis with the interdisciplinary branch of data science and data analysis. this course provides the implementation of 5g technology on intelligent transportation systems. we will generate the data, analyse it, and create an algorithm to estimate traffic patterns, behaviours, alongwith the networking capabilities of 5g. we will have major modules like software, sensing and hardware. later on we targeted the capstone project. interested candidates can register using the link or qr code provided in the course brochure (attached with this email). please find the course brochure in the attachment for syllabus, industry collaborators and other details. registration form: course registration fees : 499/- only. note : we have received sufficient registrations. the registration is open for deserving and qualified candidates in mathematics, programming, data science, and data analysis. master students can join the course, understand the prerequisite and extend their dissertation on this topic. course start date : 15th feb 2025, venue and time will convey to registered candidate through email today evening, -- *with warm regard...**..* *dr. d.chauhan* *ph.d wireless communication* *associate professor* *coordinator-career development and placement cell* *member of university-industry interaction cell* *electronics and communication engineering* *chandubhai s. patel institute of technology* *charotar university of science and technology* accredited *grade a+* by naac *mobile no : 09909454907* --
#
#
# --- ROW 13 ---
# fwd: ccna academy - introduction to basics of networking technology @ depstar in ay:2024-25 dear students, greetings for the day!!! we are excited to announce an orientation session for the *ccna* (cisco certified network associate) program, which will take place *this friday (03/01/2025) at 11:45 am* in *room 329 (sh)*. this session is open to all students interested in learning more about the ccna certification, course details, and how it can benefit your future career in networking and it. *details:* - *date:* 03/01/2025 - *time:* 11:45 am - *location:* room 329 - *resource person:* dr. amit nayak (hod dit) we encourage you to attend if you are considering pursuing ccna certification or simply want to learn more and get a better understanding of the ccna program. we look forward to seeing you there! on thu, dec 26, 2024 at 12:17 pm ritika jani <ritikajani.dit@charusat.ac.in> wrote: > *dear students,* > [image: cleardot.gif] > > greetings for the day!!! > > we are excited to announce that devang patel institute of advance > technology and research (depstar) is offering specialized networking > knowledge through the *ccna academy*, along with the opportunity to earn > the ccna certification. > > the cisco networking academy program provides students with valuable > internet technology skills through certifications like *ccna* and *ccnp*. > the goal of this program is to train and equip students to design, build, > and maintain complex computer networks, addressing the demands of the > digital economy and providing access to cutting-edge it and > telecommunications technologies. > *objectives:* > > - to provide students at depstar with highly employable it skills in > internet networking. > - to help meet the growing demand for skilled networking > professionals, reducing the need for foreign talent in the industry. > > *methodology:* > > cisco systems will supply the curriculum, training materials, and program > support needed to establish and maintain the academy. students will have > access to comprehensive online study materials, including interactive labs, > helping them develop confidence and hands-on experience in networking. the > cisco curriculum ensures the development of practical computer networking > knowledge and skills. > *scope of the certification course:* > > in today’s competitive job market, many organizations prefer professionals > with not only a degree but also relevant certifications. the cisco > certified network associate (ccna) certification is one of the most > recognized credentials in the industry. by completing the ccna program, > students will gain a deep understanding of networking principles and > concepts. > > *ccna networking competencies include:* > > - understanding computer hardware, software, electricity, networking > terminology, and protocols. > - lans and wans, osi model, ethernet, and ip addressing. > - designing and documenting basic network infrastructure and > structured cabling. > - network-to-network communication. > > *course fees:* > > - 2000 inr > > the ccna academy classes will be held on the *1st and 3rd saturdays of > each semester*. > > interested students can register by filling out the google form: > > > for more details about the course, please visit the official cisco > networking academy site: > > > course content: > > *tutor:* > > dr. amit nayak (ph.d., head of the department - information technology) > *ccna academy statistics at depstar:* > > - *ay 2017-18:* 42 students > - *ay 2018-19:* 32 students > - *ay 2019-20:* 32 students > - *ay 2020-21:* 33 students > - *ay 2021-22:* 16 students > > for any queries, feel free to reach out to *ritika jani* or *dr. amit > nayak*. > > -- > *thanks and regards,* > *ritika jani.* > *assistant professor.* > *department of information technology,* > > *devang patel institute of advance technology and research (depstar)* > *charusat, changa.* > > *"the more you sweat in practice the less you bleed in battle"* > -- *thanks and reg ...
#
#
# --- ROW 14 ---
# fwd: ccna academy - introduction to basics of networking technology @ depstar in ay:2024-25 *dear students,* [image: cleardot.gif] greetings for the day!!! we are excited to announce that devang patel institute of advance technology and research (depstar) is offering specialized networking knowledge through the *ccna academy*, along with the opportunity to earn the ccna certification. the cisco networking academy program provides students with valuable internet technology skills through certifications like *ccna* and *ccnp*. the goal of this program is to train and equip students to design, build, and maintain complex computer networks, addressing the demands of the digital economy and providing access to cutting-edge it and telecommunications technologies. *objectives:* - to provide students at depstar with highly employable it skills in internet networking. - to help meet the growing demand for skilled networking professionals, reducing the need for foreign talent in the industry. *methodology:* cisco systems will supply the curriculum, training materials, and program support needed to establish and maintain the academy. students will have access to comprehensive online study materials, including interactive labs, helping them develop confidence and hands-on experience in networking. the cisco curriculum ensures the development of practical computer networking knowledge and skills. *scope of the certification course:* in today’s competitive job market, many organizations prefer professionals with not only a degree but also relevant certifications. the cisco certified network associate (ccna) certification is one of the most recognized credentials in the industry. by completing the ccna program, students will gain a deep understanding of networking principles and concepts. *ccna networking competencies include:* - understanding computer hardware, software, electricity, networking terminology, and protocols. - lans and wans, osi model, ethernet, and ip addressing. - designing and documenting basic network infrastructure and structured cabling. - network-to-network communication. *course fees:* - 2000 inr the ccna academy classes will be held on the *1st and 3rd saturdays of each semester*. interested students can register by filling out the google form: for more details about the course, please visit the official cisco networking academy site: course content: *tutor:* dr. amit nayak (ph.d., head of the department - information technology) *ccna academy statistics at depstar:* - *ay 2017-18:* 42 students - *ay 2018-19:* 32 students - *ay 2019-20:* 32 students - *ay 2020-21:* 33 students - *ay 2021-22:* 16 students for any queries, feel free to reach out to *ritika jani* or *dr. amit nayak* . -- *thanks and regards,* *ritika jani.* *assistant professor.* *department of information technology,* *devang patel institute of advance technology and research (depstar)* *charusat, changa.* *"the more you sweat in practice the less you bleed in battle"* --
#
#
# --- ROW 15 ---
# charusat online degree programs: january 2025 admissions - apply now! [charusat] [ [naac] [ ugc entitled charusat online degree programs we are thrilled to announce ugc entitled charusat online degree programs, designed to provide flexible and accessible education to aspiring students. admissions open for january 2025 intake [icon] [ watch our new video ad film to experience the convenience and excellence of our online programs: [online degrees from charusat: a key to unlocking your potential as a working individual] [ our online programs offer: - flexible learning schedules - interactive virtual classrooms - expert faculty guidance - industry-relevant curriculum - affordable fees - live and recorded lectures - advanced lms with e-library - placement & career assistance 4 programs offered 25+ experienced faculties 240+ students enrolled why charusat online? - ugc-deb approved programs - naac a+ grade university - strong industry partnerships - alumni network - specially designed for working professionals - online proctored examination - globally accepted degree learn more > [ courses offered online bca read more → [ online mca read more → [ online bba read more → [ online mba read more → [ join the charusat family and shape your future. with enhancing your skills in business development human resources project management marketing & communication customer support design and programming charusat online programmes +91 7434055556 [/+91%207434055556] | online-admissions@charusat.ac.in [ visit us [ [charusat logo] [ [website] [ [linkedin] [ [facebook] [ [instagram] [ [youtube] [ charusat campus, off. nadiad - petlad highway, changa, gujarat 388421 © 2024 charusat. all rights reserved.
#
#
# --- ROW 16 ---
# fwd: depstar updated fees notice dear students please find revised fees notice --
#
#
# --- ROW 17 ---
# last chance to join our scholarship campaign - limited seats available! *dear students,* [image: image.png] *greetings from codeiox!* we are excited to remind you that today marks the final day of our *scholarship campaign*. as we conclude this campaign, we want to extend one last opportunity to join our exclusive training and *internship program*. *about the program:* *in collaboration with top mncs such as ibm, microsoft, deloitte, cognizant, barclays, infosys, genpact, *and* oracle*, we are offering a comprehensive *2-month online training and internship program*. this program, led by industry experts with over *10 years of experience*, is designed to provide you with valuable skills and real-world experience. *program highlights:* *1st month: learning & training* - theoretical learning from industry experts - live interactive sessions - one-to-one doubt-clearing sessions - weekly 4-5 sessions via zoom or google meet *2nd month: project & internship* - application of concepts learned in the first month - real-time projects with mentor assistance - minor project (individual) - 7 days - major project (group) - 21 days - project review by experts *3rd month: placement assistance* - placement support including mock interviews, group discussions, resume building, and personality development - placement opportunities with a potential package of up to 10 lpa *benefits of joining codeiox’s program:* 1. co-branded training completion certificate (iso and wipro approved) 2. internship completion certificate from mncs 3. outstanding/excellent performer certificate (based on performance) 4. letter of recommendation from mncs 5. real-time industrial-grade projects to enhance your resume 6. placement assistance provided 7. expert guidance from professionals working in reputed organizations like tcs, ibm, microsoft, accenture, deloitte, and more *note:* training fees are applicable. *almost done with the campaign – only 11 seats remaining for your class!* don’t miss out on this opportunity! to secure your spot, please register now using the following link: *we believe that investing in this program is an investment in your future career. explore more about our courses through online reviews and take advantage of this limited opportunity.* for any questions or further information, feel free to reach out. *best
#
#
# --- ROW 18 ---
# fwd: mysy renewal/delayed documents submission / verification year 2021, 2022 and 2023 attention dear depstar students!!! addendum ... it has been observed that a few students are having problems regarding point no. f (*sahay renewal certificate from head of the institute)* from your e-governance login, in that regard, kindly take a note as mentioned below. 1. shows less attendance in your sahay certificate : please write an application to the *respective class counselor *regarding less attendance, take remarks from the class counselor as well as *approval from the **hod of the department, *and submit the hard copy at room no. *129, depstar admin office, depstar building. * 2. for any problem in sahay certificate like - not eligible / fees not reflected: please contact at *room no*. *129, depstar admin office.* *
#
#
# --- ROW 19 ---
# fwd: c-dac hyderabad invites online applications for various contractual positions (jit 07) -- advt. no.: corp/jit/02/2024-hy dear students, find the link for c-dac hyderabad invites online applications for various contractual positions (jit 07) for your reference. advt. no.: corp/jit/02/2024-hy --- c-dac hyderabad invites online applications for various contractual positions (jit 07) advt. no.: corp/jit/02/2024-hy centre for development of advanced computing (c-dac), is a scientific society of the ministry of electronics and information technology, government of india. c-dac has today emerged as a premier r&d organization in ict&e (information, communications technologies and electronics) in the country, working on strengthening national technological capabilities in the context of global developments in the field and responding to change in the market need in selected foundation areas. c-dac represents a unique facet working in close junction with meity to implement nation’s policy and pragmatic interventions and initiatives in information technology. as an institution for high-end research and development (r&d), c-dac has been at the forefront of the information, communications technologies and electronics (ict&e) revolution, constantly building capacities in emerging/enabling technologies and innovating and leveraging its expertise, caliber and skill sets to develop and deploy products and solutions for different sectors of the economy. c-dac's areas of expertise range from r&d work in ict&e technologies to product development, ip generation, technology transfer and deployment of solutions. primary thematic or thrust areas and mission mode programmes addressed by c-dac are: primary thematic or thrust areas mission mode programmes • high performance computing and grid & cloud computing • multilingual computing & heritage computing • professional electronics, vlsi & embedded systems • software technologies including foss • cyber security & cyber forensics • health informatics • education & training • exascale computing mission • microprocessor and professional electronics mission • quantum computing mission • ai and language computing mission • internet of everything (ioe), dependable and secure computing mission • gennext applied computing mission job details: sr.post/designationno. of postsdomain(s)locationview details 1 project associate 04 cyber security, software technology (web technologies), information technology, computer technology, computer application, software system, web designing, full stack developer, software development, front end developer, network and cyber security, web developer hyderabad view details & apply 2 project associate 02 cyber security hyderabad view details & apply 3 project associate 02 software technology (web technologies), software development, web developer hyderabad view details & apply 4 project associate 05 cyber security, full stack development, electronics hardware and embedded system , software technology (web technologies), education and training, cyber security and forensics, information technology, computer technology, system security, network security, cyber forensics, system architecture, education & training, multimedia, ui / ux designer, security analyst, cloud and network security, security architecture, cloud architecture, computer networks, information security, it systems and solutions, security engineering, server system administrator, content writing, network and cyber security, web developer hyderabad view details & apply 5 project engineer 02 education and training, content writing hyderabad view details & apply 6 project engineer 10 cyber security and forensics, information technology, system security, network security, cyber forensics, data security, software development, mobile application development, security analyst, cloud and network security, security architecture, information security, business development & project management, security engineering, network ...
#
#
# --- ROW 20 ---
# mnc internship program [image: image.png] dear students, greetings from codeiox! as we are running the campaign on campus from the last 7 days it's time to end the campaign. today is the last day of the scholarship campaign. we collaborate with top mncs company [ibm ,microsoft, deloitte, cognizant, barclays, infosys, genpact, oracle etc] and organize a training and internship program on multiple domains. this is a 2-month completely online training and internship program with industry experts with 10+ years of experience!! [almost done with the campaign. hurry up 11 seats are remaining for your class] *[note : trainings fees are applicable !! ]* * register here:-* *1st month (learning/ training)* - theoretical learning from industrial experts. - live interactive sessions. - doubt clearing sessions. ( one to one session ) - weekly 4-5 sessions via zoom or google meet. * 2nd month (project / internship)* - application of concepts learned in the first month. - real-time projects with proper mentor assistance, to build an attractive resume. - minor project - individual [07 days]. - major project - group [21 days]. - project review by experts * 3rd month ** [ **placement assistance (placement package: upto 10lpa)* *]* - placement assistance [multiple sessions of mock interview, group discussion, resume building and personality development, placement assistance will be given to you, which will make you stand out in the placement procedure.] - giving placement opportunity by conducting a online exam *[ benefits of the codeiox's training and internship opportunities: ]* 1. training completion certificate co-branded with iso and wipro approved. 2. internship completion certificate from mncs. 3. outstanding/ excellent performer certificate [ depends on your performance] 4. letter of recommendation from mncs for job reference. 5. real-time industrial-grade projects to enhance your resume/cv. 6. placement assistance provided to the candidates. 7. meticulous guidance under industry experts who work in reputed organizations like tcs, ibm, microsoft, accenture, cognizant, pwc, j.p. morgan, deloitte, etc talend and many more. *[we believe investment in the courses is an investment for a better career. therefore, we suggest you explore and register for these courses. you can always watch reviews of our courses on google.]* -- *limited seats are available. so grab the opportunity and fill this form now !* *anjali bathula* *educational counselor* *codeiox edutech*

# %%
label_df = df[[
    "sender_email",
    "sender_domain",
    "subject",
    
    
    "clean_text",
    "deadline_date",
    "label_source",
    "label_topic",
    "label_urgency"
]]

# %%
label_df.head()
# Out:
#                      sender_email     sender_domain  \
# 0        23dcs023@charusat.edu.in   charusat.edu.in
# 1        23dcs023@charusat.edu.in   charusat.edu.in
# 2  onlinecourses@nptel.iitm.ac.in  nptel.iitm.ac.in
# 4               support@e.read.ai         e.read.ai
# 5  mohinidarji.dcs@charusat.ac.in    charusat.ac.in
#
#                                              subject  \
# 0  Request for Email Data Contribution – Research...
# 1  Re: Request for Email Data Contribution – Rese...
# 2  NPTEL Newsletter: IIT Madras CODE Certificate ...
# 4          Exclusive Education Pricing Just for You!
# 5             Reg. Submission of SGP- Weekly reports
#
#                                           clean_text deadline_date  \
# 0  request for email data contribution – research...
# 1  re: request for email data contribution – rese...
# 2  nptel newsletter: iit madras code certificate ...
# 4  exclusive education pricing just for you! read...
# 5  reg. submission of sgp- weekly reports dear st...
#
#   label_source label_topic label_urgency
# 0
# 1
# 2
# 4
# 5

# %%
label_df.to_csv("unlabeled_dataset.csv",index=False)

# %% [markdown]
# #locked the dataset down for level1 labelling, level2 labelling and llm inference later
