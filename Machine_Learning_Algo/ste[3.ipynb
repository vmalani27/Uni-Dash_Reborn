# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Vansh Malani\Documents\GitHub\Uni-Dash_Reborn\Machine_Learning_Algo\labeled_dataset.csv")

# %%
df.head()
# Out:
#                                                 from  \
# 0  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....
# 1  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....
# 2             NPTEL <onlinecourses@nptel.iitm.ac.in>
# 3  "Parth Goel (Classroom)" <no-reply@classroom.g...
# 4                   Team at Read <support@e.read.ai>
#
#                                            full_text  label
# 0  Request for Email Data Contribution – Research...    NaN
# 1  Re: Request for Email Data Contribution – Rese...    NaN
# 2  NPTEL Newsletter: IIT Madras CODE Certificate ...    NaN
# 3  New announcement: "s, You are requested to…" N...    NaN
# 4  Exclusive Education Pricing Just for You! Read...    NaN
