# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("output_20260103_222919/source_labeled_dataset.csv")

# %%
df
# Out:
#                               sender_email     sender_domain  \
# 0                 23dcs023@charusat.edu.in   charusat.edu.in
# 1                 23dcs023@charusat.edu.in   charusat.edu.in
# 2           onlinecourses@nptel.iitm.ac.in  nptel.iitm.ac.in
# 3                        support@e.read.ai         e.read.ai
# 4           mohinidarji.dcs@charusat.ac.in    charusat.ac.in
# ...                                    ...               ...
# 1531  iitbhubaneswartrainingcell@gmail.com         gmail.com
# 1532        krishnapatel.ce@charusat.ac.in    charusat.ac.in
# 1533  vaishalivadhavana.dcs@charusat.ac.in    charusat.ac.in
# 1534               mail-noreply@google.com        google.com
# 1535               mail-noreply@google.com        google.com
#
#                                                 subject  \
# 0     Request for Email Data Contribution – Research...
# 1     Re: Request for Email Data Contribution – Rese...
# 2     NPTEL Newsletter: IIT Madras CODE Certificate ...
# 3             Exclusive Education Pricing Just for You!
# 4                Reg. Submission of SGP- Weekly reports
# ...                                                 ...
# 1531  Exclusive Upskilling Program for CHARUSAT Firs...
# 1532                    CE143- CCP Unit tese-1 Syllabus
# 1533  Regarding Permanent Student ID for FY 2023 CSE...
# 1534                      Tips for using your new inbox
# 1535                         Get the official Gmail app
#
#                                              clean_text  deadline_date  \
# 0     request for email data contribution – research...            NaN
# 1     re: request for email data contribution – rese...            NaN
# 2     nptel newsletter: iit madras code certificate ...            NaN
# 3     exclusive education pricing just for you! read...            NaN
# 4     reg. submission of sgp- weekly reports dear st...            NaN
# ...                                                 ...            ...
# 1531  exclusive upskilling program for charusat firs...            NaN
# 1532  ce143- ccp unit tese-1 syllabus dear students,...            NaN
# 1533  regarding permanent student id for fy 2023 cse...            NaN
# 1534  tips for using your new inbox tips for using y...            NaN
# 1535  get the official gmail app get the official gm...            NaN
#
#                   label_source  label_topic  label_urgency
# 0               Student / Club          NaN            NaN
# 1               Student / Club          NaN            NaN
# 2     External Course Provider          NaN            NaN
# 3              Misc / External          NaN            NaN
# 4     Faculty / Academic Staff          NaN            NaN
# ...                        ...          ...            ...
# 1531           Misc / External          NaN            NaN
# 1532  Faculty / Academic Staff          NaN            NaN
# 1533   Administration / Office          NaN            NaN
# 1534           Misc / External          NaN            NaN
# 1535           Misc / External          NaN            NaN
#
# [1536 rows x 8 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    stop_words="english",
    max_features=8000,
    ngram_range=(1,2)
)

X = vectorizer.fit_transform(df["clean_text"])
y = df["label_source"]   # or label_source

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=1000)
clf.fit(X, y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
import numpy as np

feature_names = np.array(vectorizer.get_feature_names_out())

for i, label in enumerate(clf.classes_):
    top_idx = np.argsort(clf.coef_[i])[-15:]
    print(f"\nLabel: {label}")
    print(feature_names[top_idx])
# Out:
# Label: Administration / Office
# ['ac' 'course' '2024' 'fees' 'semester' 'governance' 'internal' 'viva'
#  'university' 'schedule' 'scholarship' 'scheme' 'students' 'exam'
#  'examination']
#
# Label: External Course Provider
# ['live nan' 'base' 'analysis' 'base management' 'data base' 'released nan'
#  'week' 'algorithms' 'programming' 'design analysis' 'analysis algorithms'
#  'java' 'programming java' 'nptel' 'nan']
#
# Label: Faculty / Academic Staff
# ['date' 'ac' 'classroom' 'reg' 'patel' 'quiz' 'charusat ac' 'ccp' 'dr'
#  '2023' 'aws' 'students' 'submission' 'charusat' 'india']
#
# Label: Misc / External
# ['training' 'cisco' 'verification' 'hackerrank' 'month' 'read' 'google'
#  'program' 'leetcode' '23dcs023' 'form' 'recommended' 'account'
#  'kodekloud' 'internship']
#
# Label: Student / Club
# ['research' 'counsellor' 'interview' 'request' 'agevole'
#  'research project' 'email data' '23dcs027' 'vansh' 'contribution'
#  'dhandhukiya' 'student' 'james dhandhukiya' 'james' 'ieee']
