# %%
import pandas as pd
import re

# %%
#input dataset unclean, and noisy

df_path = "D:\\vanshmalanidata\\Documents\\GitHub\\Uni-Dash_Reborn\\data"
df = pd.read_csv(df_path + "\\23DCS023_all_emails.csv")

# %%
USER_EMAIL = "23dcs023@charusat.edu.in"

# ---------------------------------------------------
# 1. REMOVE CHARUSAT DISCLAIMER
# ---------------------------------------------------
def remove_charusat_disclaimer(text):
    # Remove only the long legal footer, not message body
    pattern = r"(?is)disclaimer[:].*"
    return re.sub(pattern, "", str(text)).strip()


# ---------------------------------------------------
# 2. CLEAN TEXT
# ---------------------------------------------------
def clean_text(text):
    text = str(text)

    text = remove_charusat_disclaimer(text)

    # Remove generic signatures (keep forwarded content intact)
    text = re.sub(
        r"(?is)(thanks[,.]?$|regards[,.]?$|warm regards[,.]?$|best wishes[,.]?$)",
        "",
        text
    )

    # Remove long signature blocks if they are at the end (200 chars max)
    text = re.sub(r"(?is)(thanks|regards)[\s\S]{0,200}$", "", text)

    # Replace URLS using tokens for privacy
    text = re.sub(r"http\S+|www\.\S+", " <URL> ", text)


    # Collapse extra whitespace
    text = re.sub(r"\s+", " ", text).strip()

    return text.lower()


# ---------------------------------------------------
# 3. EMAIL + DOMAIN EXTRACTION
# ---------------------------------------------------
def extract_email(text):
    match = re.search(r'[\w\.-]+@[\w\.-]+', str(text))
    return match.group(0).lower() if match else ""

def extract_domain(email):
    return email.split('@')[-1] if "@" in email else ""




# ---------------------------------------------------
# 6. PIPELINE
# ---------------------------------------------------
cols_to_drop = ["Unnamed: 0", "id", "threadId", "labelIds", "snippet"]
df = df.drop(columns=[c for c in cols_to_drop if c in df.columns], errors="ignore")

df["raw_text"] = df["subject"].astype(str) + " " + df["content"].astype(str)
df["clean_text"] = df["raw_text"].apply(clean_text)

df["sender_email"] = df["from"].apply(extract_email)
df["sender_domain"] = df["sender_email"].apply(extract_domain)
    
df["label_source"] = ""
df["label_topic"] = ""
df["label_urgency"] = ""


# ---------------------------------------------------
# 7. FILTERING RULES
# ---------------------------------------------------

# Delete autosent classroom mails ( there is no point in keeping them)
df = df[df["sender_email"].str.lower() != "no-reply@classroom.google.com"]


# Keep short tiny urgent mails
df = df[df["clean_text"].str.len() > 5].reset_index(drop=True)

#remove self mails

df = df[df["sender_email"].str.lower() != USER_EMAIL]

df.head()
# Out:
#                                                 from  \
# 2             NPTEL <onlinecourses@nptel.iitm.ac.in>
# 3                   Team at Read <support@e.read.ai>
# 4      Mohini Darji <mohinidarji.dcs@charusat.ac.in>
# 5  Pinterest <recommendations@discover.pinterest....
# 6     Sanket Suthar <sanketsuthar.it@charusat.ac.in>
#
#                                              subject  \
# 2  NPTEL Newsletter: IIT Madras CODE Certificate ...
# 3          Exclusive Education Pricing Just for You!
# 4             Reg. Submission of SGP- Weekly reports
# 5                    Interaction Design for 23DCS023
# 6  AWS Academy Batch Starting – 5th July, 10:30 A...
#
#                         date  \
# 2  2025-06-25 15:52:01+05:30
# 3  2025-06-25 09:33:48+00:00
# 4  2025-06-25 13:36:47+05:30
# 5  2025-06-25 07:23:14+00:00
# 6  2025-06-25 10:09:42+05:30
#
#                                              content  \
# 2  <https://code.iitm.ac.in/foundations-to-ml>\r\...
# ...

# %%
print(f"the columns in the dataset are {df.columns} and there are a total of {len(df)} mails")
# Out:
# the columns in the dataset are Index(['from', 'subject', 'date', 'content', 'raw_text', 'clean_text',
#        'sender_email', 'sender_domain', 'label_source', 'label_topic',
#        'label_urgency'],
#       dtype='object') and there are a total of 1522 mails

# %% [markdown]
# <h1>we want to reduce the features</h1>

# %%
unlabel_df = df[[
    "sender_email",
    "sender_domain",
    "subject",
    
    
    "clean_text",
    "label_source",
    "label_topic",
    "label_urgency"
]]

# %%
unlabel_df.to_csv("unlabeled_dataset.csv",index=False)

# %% [markdown]
# #locked the dataset down for level1 labelling, level2 labelling and llm inference later

# %% [markdown]
# <h1>now we move on to level 1 ie label source<h1>

# %%
from html import unescape
import os
from datetime import datetime

# %% [markdown]
# <h2>lets define the paths and input output</h2>

# %%
INPUT_FILE = "unlabeled_dataset.csv"
# OUTPUT_FILE = "source_labeled_dataset.csv"

# Output will be saved in a timestamped folder
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
OUTPUT_DIR = f"output_{timestamp}"
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_FILE = os.path.join(OUTPUT_DIR, "source_labeled_dataset.csv")

INPUT_FILE = "unlabeled_dataset.csv"
# OUTPUT_FILE = "source_labeled_dataset.csv"

# Output will be saved in a timestamped folder
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
OUTPUT_DIR = f"output_{timestamp}"
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_FILE = os.path.join(OUTPUT_DIR, "source_labeled_dataset.csv")

# %% [markdown]
# # ----------------------------------------------------------
# # Level-1: Source Trust Classification (Identity-only)
# # ----------------------------------------------------------

# %%
EXTERNAL_ACADEMIC_DOMAINS = {
    "nptel.iitm.ac.in",
    "nptel.ac.in",
    "coursera.org",
    "edx.org",
}

# %%
def classify_level1(sender_domain: str) -> str:
    """
    Level-1 classification determines the institutional trust level
    of the sender. It does NOT infer intent or topic.
    """

    sender_domain = (sender_domain or "").lower().strip()

    if not sender_domain:
        return "External / Misc"

    if sender_domain in EXTERNAL_ACADEMIC_DOMAINS:
        return "External Academic Platform"

    if sender_domain.endswith("charusat.ac.in"):
        return "Institutional Sender"

    if sender_domain.endswith("charusat.edu.in"):
        return "Student / Peer"

    return "External / Misc"

# %%
level1_df=pd.read_csv(INPUT_FILE, dtype=str, keep_default_na=False)

# %%
level1_df
# Out:
#                                 sender_email           sender_domain  \
# 0             onlinecourses@nptel.iitm.ac.in        nptel.iitm.ac.in
# 1                          support@e.read.ai               e.read.ai
# 2             mohinidarji.dcs@charusat.ac.in          charusat.ac.in
# 3     recommendations@discover.pinterest.com  discover.pinterest.com
# 4             sanketsuthar.it@charusat.ac.in          charusat.ac.in
# ...                                      ...                     ...
# 1517    iitbhubaneswartrainingcell@gmail.com               gmail.com
# 1518          krishnapatel.ce@charusat.ac.in          charusat.ac.in
# 1519    vaishalivadhavana.dcs@charusat.ac.in          charusat.ac.in
# 1520                 mail-noreply@google.com              google.com
# 1521                 mail-noreply@google.com              google.com
#
#                                                 subject  \
# 0     NPTEL Newsletter: IIT Madras CODE Certificate ...
# ...

# %% [markdown]
# <h2>applying source labels</h2>

# %%
level1_df["label_source"] = level1_df.apply(
        lambda r: classify_level1(
            r.get("sender_domain", ""),
        ),
        axis=1
    )

# %%
level1_df.to_csv(OUTPUT_FILE, index=False)

# %%
level1_df=pd.read_csv(OUTPUT_FILE)

# %%
level1_df
# Out:
#                                 sender_email           sender_domain  \
# 0             onlinecourses@nptel.iitm.ac.in        nptel.iitm.ac.in
# 1                          support@e.read.ai               e.read.ai
# 2             mohinidarji.dcs@charusat.ac.in          charusat.ac.in
# 3     recommendations@discover.pinterest.com  discover.pinterest.com
# 4             sanketsuthar.it@charusat.ac.in          charusat.ac.in
# ...                                      ...                     ...
# 1517    iitbhubaneswartrainingcell@gmail.com               gmail.com
# 1518          krishnapatel.ce@charusat.ac.in          charusat.ac.in
# 1519    vaishalivadhavana.dcs@charusat.ac.in          charusat.ac.in
# 1520                 mail-noreply@google.com              google.com
# 1521                 mail-noreply@google.com              google.com
#
#                                                 subject  \
# 0     NPTEL Newsletter: IIT Madras CODE Certificate ...
# ...

# %%
level1_df["label_source"].value_counts()
# Out:
# label_source
# Institutional Sender          918
# External / Misc               430
# External Academic Platform    140
# Student / Peer                 34
# Name: count, dtype: int64

# %% [markdown]
# <h1> now we will shrink the dataset for llm inference</h1>

# %%
shrink_size = {
    "Institutional Sender": 70,
    "External / Misc": 40,
    "External Academic Platform": 25,
    "Student / Peer": 15,
}

# %%
samples = []

for source, n in shrink_size.items():
    subset = level1_df[level1_df["label_source"] == source]
    samples.append(subset.sample(n=n, random_state=42))

eval_df = pd.concat(samples).sample(frac=1, random_state=42).reset_index(drop=True)

eval_df.to_csv("llm_eval_subset_v1.csv", index=False)

# %%
print(eval_df["label_source"].value_counts())
# Out:
# label_source
# Institutional Sender          70
# External / Misc               40
# External Academic Platform    25
# Student / Peer                15
# Name: count, dtype: int64

# %% [markdown]
# <h1>now it is time for llm inference</h1>

# %%
import os
import json
import requests
from datetime import datetime

# %%
INPUT_FILE = "llm_eval_subset_v1.csv"   # output of Level-1


OLLAMA_MODELS = [
    "qwen2.5:7b-instruct-q4_k_m",
    "mistral:7b-instruct-q4_k_m",
    #"phi3:medium-4k-instruct-q4_k_m",
]

OLLAMA_URL = "http://127.0.0.1:11434/api/generate"

LEVEL2_LABELS = [
    "Timetable / Schedule Update",
    "Exam Notifications",
    "Assignment or Submission",
    "Certification / Courses",
    "Internship / Placement Opportunities",
    "Events / Hackathons",
    "Important Announcements",
    "Administrative / Fees / Counselling",
    "General Information / Misc",
]

URGENCY_LABELS = ["Critical", "High", "Medium", "Low", "None"]

# %%
SYSTEM_PROMPT = f"""
You are an academic email assistant for a university student.

You will receive:
- SOURCE TRUST LEVEL (who sent the email)
- EMAIL SUBJECT
- EMAIL BODY

Important rules:
- Emails may be forwarded by faculty on behalf of administrative offices.
- Do NOT infer authority based only on sender.
- Decide topic and urgency from language, enforcement cues, deadlines, and tone.
- Output must be strictly valid JSON.
- Do NOT add explanations outside JSON.

Allowed topic labels:
{LEVEL2_LABELS}

Urgency definitions:
- Critical: deadline today or tomorrow; penalties if missed
- High: deadline within a few days; important action required
- Medium: relevant academic info, no immediate deadline
- Low: optional events or learning opportunities
- None: newsletters, promotions, routine info

Return JSON in this exact format:
{{
  "summary": "<one-line student-facing summary>",
  "label_topic": "<one of the allowed topic labels>",
  "label_urgency": "<one of the urgency labels>"
}}
"""

# %%
# ----------------------------------------------------------
# LLM Call
# ----------------------------------------------------------

def classify_email(label_source, subject, clean_text, model_name):
    prompt = f"""
SOURCE TRUST LEVEL: {label_source}
SUBJECT: {subject}

EMAIL CONTENT:
{clean_text}
"""

    response = requests.post(
        OLLAMA_URL,
        json={
            "model": model_name,
            "prompt": SYSTEM_PROMPT + "\n" + prompt,
            "stream": False,
            "options": {
                "temperature": 0,
                "top_p": 0.1
            }
        },
        timeout=60
    )

    response.raise_for_status()
    raw_output = response.json().get("response", "").strip()

    # ---- PRINT RAW LLM OUTPUT ----
    print("\n===== LLM RAW OUTPUT =====")
    print(raw_output)
    print("==========================\n")

    try:
        parsed = json.loads(raw_output)

        # ---- PRINT PARSED OUTPUT ----
        print(">>> PARSED RESULT:")
        print(parsed)
        print()

        return parsed

    except json.JSONDecodeError:
        print("!!! JSON PARSE FAILED — FALLING BACK !!!\n")
        return {
            "summary": "",
            "label_topic": "General Information / Misc",
            "label_urgency": "None"
        }

# %% [markdown]
# <h1>llm inference</h1>

# %%
emails_df = pd.read_csv(INPUT_FILE, dtype=str, keep_default_na=False)

# %%
emails_df
# Out:
#                                       sender_email           sender_domain  \
# 0           recommendations@discover.pinterest.com  discover.pinterest.com
# 1                   nainaparmar.dcs@charusat.ac.in          charusat.ac.in
# 2                   onlinecourses@nptel.iitm.ac.in        nptel.iitm.ac.in
# 3                  netacademail@external.cisco.com      external.cisco.com
# 4                     no-reply@accounts.google.com     accounts.google.com
# ..                                             ...                     ...
# 145  pinterest-recommendations@ideas.pinterest.com     ideas.pinterest.com
# 146                             team@kodekloud.com           kodekloud.com
# 147                kirtimakwana.mba@charusat.ac.in          charusat.ac.in
# 148                    tanisha.singh@teachnook.com           teachnook.com
# 149                          no-reply@leetcode.com            leetcode.com
#
#                                                subject  \
# ...

# %%
# Pick up to 10 emails, stratified by label_source
sampled_rows = []

for source in emails_df["label_source"].unique():
    subset = emails_df[emails_df["label_source"] == source]
    if not subset.empty:
        sampled_rows.append(subset.sample(n=1, random_state=42))

sampled_df = pd.concat(sampled_rows).head(10).reset_index(drop=True)

print(sampled_df["label_source"].value_counts())
# Out:
# label_source
# External / Misc               1
# Institutional Sender          1
# External Academic Platform    1
# Student / Peer                1
# Name: count, dtype: int64

# %%
for model_name in OLLAMA_MODELS:
    print("\n" + "=" * 100)
    print(f"STARTING INFERENCE WITH MODEL: {model_name}")
    print("=" * 100 + "\n")

    for idx, row in sampled_df.iterrows():
        print("\n" + "-" * 80)
        print(f"EMAIL {idx + 1}")
        print(f"SOURCE: {row['label_source']}")
        print(f"SUBJECT: {row.get('subject', '')}")
        print(f"BODY:\n{row['clean_text']}")
        print("-" * 80)

        result = classify_email(
            label_source=row["label_source"],
            subject=row.get("subject", ""),
            clean_text=row.get("clean_text", ""),
            model_name=model_name
        )

        print("FINAL OUTPUT:")
        print(result)

    cont_model = input(
        f"\nFinished all emails for model '{model_name}'. "
        "Continue to next model? (y/n): "
    ).strip().lower()

    if cont_model != "y":
        break
# Out:
# ...
# STARTING INFERENCE WITH MODEL: qwen2.5:7b-instruct-q4_k_m
# ...
#
#
# --------------------------------------------------------------------------------
# EMAIL 1
# SOURCE: External / Misc
# SUBJECT: INVITATION FOR INTERNSHIP AND JOB ASSISTANCE WITH IIT-BHUBANESWAR
# BODY:
# ...

# %%
# ----------------------------------------------------------
# 1. Create balanced subset of 200 emails (UNCHANGED)
# ----------------------------------------------------------

TOTAL_SAMPLES = 200
sources = emails_df["label_source"].unique().tolist()
num_sources = len(sources)
samples_per_source = TOTAL_SAMPLES // num_sources

sampled_parts = []

for source in sources:
    subset = emails_df[emails_df["label_source"] == source]
    
    if len(subset) <= samples_per_source:
        sampled_parts.append(subset)
    else:
        sampled_parts.append(
            subset.sample(n=samples_per_source, random_state=42)
        )

sampled_df = pd.concat(sampled_parts, ignore_index=True)

# Top-up if needed (safe version)
if len(sampled_df) < TOTAL_SAMPLES:
    remaining = emails_df.drop(sampled_df.index, errors="ignore")
    extra_needed = TOTAL_SAMPLES - len(sampled_df)

    if len(remaining) > 0:
        extra_to_take = min(extra_needed, len(remaining))

        sampled_df = pd.concat(
            [
                sampled_df,
                remaining.sample(n=extra_to_take, random_state=42)
            ],
            ignore_index=True
        )


# ----------------------------------------------------------
# 2. Run LLM inference (MODEL → EMAILS)
# ----------------------------------------------------------

for model_name in OLLAMA_MODELS:
    print("\n" + "=" * 100)
    print(f"RUNNING MODEL: {model_name}")
    print("=" * 100 + "\n")

    # Work on a fresh copy per model
    model_df = sampled_df.copy()
    model_df["summary"] = ""
    model_df["label_topic"] = ""
    model_df["label_urgency"] = ""

    for idx, row in model_df.iterrows():
        result = classify_email(
            label_source=row["label_source"],
            subject=row.get("subject", ""),
            clean_text=row.get("clean_text", ""),
            model_name=model_name
        )

        model_df.at[idx, "summary"] = result.get("summary", "")
        model_df.at[idx, "label_topic"] = result.get("label_topic", "")
        model_df.at[idx, "label_urgency"] = result.get("label_urgency", "")

        if idx % 25 == 0:
            print(f"[{model_name}] Processed {idx} / {len(model_df)} emails")

    # ----------------------------------------------------------
    # 3. Save per-model output into EXISTING run directory
    # ----------------------------------------------------------

    safe_model_name = model_name.replace(":", "_").replace("-", "_")
    LLM_OUTPUT_FILE = os.path.join(
        OUTPUT_DIR,
        f"llm_labeled_{safe_model_name}.csv"
    )

    model_df.to_csv(LLM_OUTPUT_FILE, index=False, encoding="utf-8")
    print(f"\nSaved results for model '{model_name}' to:")
    print(LLM_OUTPUT_FILE)

    cont_model = input(
        f"\nFinished model '{model_name}'. Continue to next model? (y/n): "
    ).strip().lower()

    if cont_model != "y":
        break
# Out:
# ...
# RUNNING MODEL: qwen2.5:7b-instruct-q4_k_m
# ...
#
#
# ===== LLM RAW OUTPUT =====
# {
#   "summary": "Access the form design for module 23DCS023 via provided URL.",
#   "label_topic": "General Information / Misc",
#   "label_urgency": "None"
# }
# ...
#
# >>> PARSED RESULT:
# {'summary': 'Access the form design for module 23DCS023 via provided URL.', 'label_topic': 'General Information / Misc', 'label_urgency': 'None'}
#
# [qwen2.5:7b-instruct-q4_k_m] Processed 0 / 150 emails
#
# ===== LLM RAW OUTPUT =====
# {
#   "summary": "NetAcad Student Newsletter highlights new platform features and upcoming events.",
#   "label_topic": "General Information / Misc",
#   "label_urgency": "Medium"
# }
# ...
#
# >>> PARSED RESULT:
# {'summary': 'NetAcad Student Newsletter highlights new platform features and upcoming events.', 'label_topic': 'General Information / Misc', 'label_urgency': 'Medium'}
#
#
# ===== LLM RAW OUTPUT =====
# {
#   "summary": "Google alerts you of a recent sign-in on your account.",
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 # Pick up to 10 emails, stratified by label_source
#       2 sampled_rows = []
# ----> 4 for source in emails_df["label_source"].unique():
#       5     subset = emails_df[emails_df["label_source"] == source]
#       6     if not subset.empty:
#
# NameError: name 'emails_df' is not defined

# %%
# ----------------------------------------------------------

# Model Evaluation Metrics

# ----------------------------------------------------------

import pandas as pd

from sklearn.metrics import classification_report, accuracy_score, confusion_matrix


# Load ground truth and model predictions

ground_truth = pd.read_csv("evaluation_dataset_ground_truth.csv", dtype=str, keep_default_na=False)

# Replace with the actual model output file you want to evaluate

model_output = pd.read_csv(OUTPUT_FILE, dtype=str, keep_default_na=False)


# Ensure columns match for comparison

# For example, compare 'label_topic' and 'label_urgency'

for label in ["label_topic", "label_urgency"]:
    print(f"\n=== Evaluation for {label} ===")
    y_true = ground_truth[label]
    y_pred = model_output[label]
    print(classification_report(y_true, y_pred))
    print("Confusion Matrix:")
    print(confusion_matrix(y_true, y_pred))
    print(f"Accuracy: {accuracy_score(y_true, y_pred):.4f}")
