# %%
import pandas as pd

# %%
df_path = "C:\\Users\\Vansh Malani\\Documents\\GitHub\\Uni-Dash_Reborn\\data"
df = pd.read_csv(df_path + "\\23DCS023_all_emails.csv")
# df=pd.read_csv("labeled_dataset.csv")

# %%
import re
import pandas as pd

# ---------------------------------------------------
# 1. REMOVE CHARUSAT DISCLAIMER
# ---------------------------------------------------
def remove_charusat_disclaimer(text):
    # Remove only the long legal footer, not message body
    pattern = r"(?is)disclaimer[:].*"
    return re.sub(pattern, "", str(text)).strip()


# ---------------------------------------------------
# 2. CLEAN TEXT
# ---------------------------------------------------
def clean_text(text):
    text = str(text)

    text = remove_charusat_disclaimer(text)

    # Remove generic signatures (keep forwarded content intact)
    text = re.sub(
        r"(?is)(thanks[,.]?$|regards[,.]?$|warm regards[,.]?$|best wishes[,.]?$)",
        "",
        text
    )

    # Remove long signature blocks if they are at the end (200 chars max)
    text = re.sub(r"(?is)(thanks|regards)[\s\S]{0,200}$", "", text)

    # Remove URLs only
    text = re.sub(r"http\S+|www\.\S+", "", text)

    # Collapse extra whitespace
    text = re.sub(r"\s+", " ", text).strip()

    return text.lower()


# ---------------------------------------------------
# 3. EMAIL + DOMAIN EXTRACTION
# ---------------------------------------------------
def extract_email(text):
    match = re.search(r'[\w\.-]+@[\w\.-]+', str(text))
    return match.group(0).lower() if match else ""

def extract_domain(email):
    return email.split('@')[-1] if "@" in email else ""


# ---------------------------------------------------
# 4. FLAGS
# ---------------------------------------------------
def contains_submit_word(text):
    return bool(re.search(r"\b(submit|upload|last date|due|fill)\b", text))

def contains_exam_word(text):
    return bool(re.search(r"\b(exam|test|cie|hall ticket|seating)\b", text))

def contains_event_word(text):
    return bool(re.search(r"\b(hackathon|event|bootcamp|seminar|workshop|competition)\b", text))

def contains_form_link(text):
    return bool(re.search(r"(docs\.google\.com/forms|forms\.gle)", text))


# ---------------------------------------------------
# 5. DEADLINE EXTRACTION
# ---------------------------------------------------
def extract_deadline(text):
    pattern = r"(due|deadline|submit by|last date)[:\- ]*(\d{1,2}[/-]\d{1,2}[/-]\d{2,4}|\d{1,2}\s+\w+\s+\d{4})"
    m = re.search(pattern, text, re.IGNORECASE)
    return m.group(2) if m else ""


# ---------------------------------------------------
# 6. PIPELINE
# ---------------------------------------------------
cols_to_drop = ["Unnamed: 0", "id", "threadId", "labelIds", "snippet"]
df = df.drop(columns=[c for c in cols_to_drop if c in df.columns], errors="ignore")

df["raw_text"] = df["subject"].astype(str) + " " + df["content"].astype(str)
df["clean_text"] = df["raw_text"].apply(clean_text)

df["sender_email"] = df["from"].apply(extract_email)
df["sender_domain"] = df["sender_email"].apply(extract_domain)

df["contains_submit_word"] = df["clean_text"].apply(contains_submit_word)
df["contains_exam_word"] = df["clean_text"].apply(contains_exam_word)
df["contains_event_word"] = df["clean_text"].apply(contains_event_word)
df["contains_form_link"] = df["clean_text"].apply(contains_form_link)

df["deadline_date"] = df["clean_text"].apply(extract_deadline)
df["contains_deadline"] = df["deadline_date"].apply(lambda x: bool(x))

df["label_source"] = ""
df["label_topic"] = ""
df["label_urgency"] = ""


# ---------------------------------------------------
# 7. FILTERING RULES
# ---------------------------------------------------

# Delete ONLY pure system messages (not real emails)
df = df[~df["from"].str.contains(r"^no-reply@classroom\.google\.com$", na=False, case=False)]

# Keep short tiny urgent mails
df = df[df["clean_text"].str.len() > 5].reset_index(drop=True)

df.head()
# Out:
#                                                 from  \
# 0  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....
# 1  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....
# 2             NPTEL <onlinecourses@nptel.iitm.ac.in>
# 3                   Team at Read <support@e.read.ai>
# 4      Mohini Darji <mohinidarji.dcs@charusat.ac.in>
#
#                                              subject  \
# 0  Request for Email Data Contribution – Research...
# 1  Re: Request for Email Data Contribution – Rese...
# 2  NPTEL Newsletter: IIT Madras CODE Certificate ...
# 3          Exclusive Education Pricing Just for You!
# 4             Reg. Submission of SGP- Weekly reports
#
#                         date  \
# 0  2025-06-25 20:36:16+05:30
# 1  2025-06-25 20:31:44+05:30
# 2  2025-06-25 15:52:01+05:30
# 3  2025-06-25 09:33:48+00:00
# 4  2025-06-25 13:36:47+05:30
#
#                                              content  \
# 0  Dear Student\r\n\r\nThank you so much for your...
# 1  I hope you're doing well.\r\n\r\nThis is a fin...
# 2  <https://code.iitm.ac.in/foundations-to-ml>\r\...
# 3  Read AI for $5 Per Month\r\nHi 23DCS023 , as a...
# 4  Dear Students,\r\n\r\nKindly find the attached...
#
#                                             raw_text  \
# 0  Request for Email Data Contribution – Research...
# 1  Re: Request for Email Data Contribution – Rese...
# 2  NPTEL Newsletter: IIT Madras CODE Certificate ...
# 3  Exclusive Education Pricing Just for You! Read...
# 4  Reg. Submission of SGP- Weekly reports Dear St...
#
#                                           clean_text  \
# 0  request for email data contribution – research...
# 1  re: request for email data contribution – rese...
# 2  nptel newsletter: iit madras code certificate ...
# 3  exclusive education pricing just for you! read...
# 4  reg. submission of sgp- weekly reports dear st...
#
#                      sender_email     sender_domain  contains_submit_word  \
# 0        23dcs023@charusat.edu.in   charusat.edu.in                 False
# 1        23dcs023@charusat.edu.in   charusat.edu.in                  True
# 2  onlinecourses@nptel.iitm.ac.in  nptel.iitm.ac.in                 False
# 3               support@e.read.ai         e.read.ai                 False
# 4  mohinidarji.dcs@charusat.ac.in    charusat.ac.in                  True
#
#    contains_exam_word  contains_event_word  contains_form_link deadline_date  \
# 0               False                False               False
# 1               False                False               False
# 2               False                False               False
# 3               False                False               False
# 4               False                False               False
#
#    contains_deadline label_source label_topic label_urgency
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %%
# Remove emails from classroom.google.com domain
df = df[~df["sender_domain"].str.contains(r"classroom\.google\.com$", na=False, case=False)]

# %%
df.columns
# Out:
# Index(['from', 'subject', 'date', 'content', 'raw_text', 'clean_text',
#        'sender_email', 'sender_domain', 'contains_submit_word',
#        'contains_exam_word', 'contains_event_word', 'contains_form_link',
#        'deadline_date', 'contains_deadline', 'label_source', 'label_topic',
#        'label_urgency'],
#       dtype='object')

# %%
# Find rows where clean_text contains the keyword 'fees' (case-insensitive) and display them
fees_rows = df[df['clean_text'].str.contains('fees', case=False, na=False)]
fees_rows
# Out:
#                                                    from  \
# 26      Gaurang Patel <gaurangpatel.dcs@charusat.ac.in>
# 1083  Fwd: EC-Council Academia Cost for Network Defe...
# 1158  CHARUSAT_FTE_DEPSTAR_CSE_Certificate Course in...
# 1221  Shepreneur - A stall showcase competition on 7...
# 1255  Re: CCNA Academy - Introduction to Basics of N...
# 1256  Re: Supplementary Examination - 1_ Schedule fo...
# 1259  CCNA Academy - Introduction to Basics of Netwo...
# 1290  Supplementary Examination - 1_ Schedule for B....
# 1295  ***NATIONAL LEVEL TRAINING AND INTERNSHIP CAMP...
# 1315  Fwd: FW: Call for Participation in “Poster Com...
# 1321  Re: Examination Guidelines Dear Students,\r\n\...
# 1324  Final Call To Apply Training and Internship Pr...
# 1342  Examination Guidelines Dear Students,\r\n\r\nT...
# 1380  Fwd: Notice of Fees Payment Dear Students,\r\n...
# 1469  IMP: ONLINE TRAINING AND INTERNSHIP CAMPAIGN *...
#
#                                              clean_text  \
# 26    semester 5 fee payment schedule - b.tech progr...
# 87    nptel newsletter: june 2025: vol 6: week 2! np...
# 129   weekly kickoff | mon, may 26th | read.ai need ...
# 158   fwd: proposal for students to participate in t...
# 159   fwd: proposal for students to participate in t...
# 160   fwd: proposal for students to participate in t...
# 171   weekly kickoff | mon, may 19th | read.ai need ...
# 289   re: university theory and practical examinatio...
# 293   accenture accredited internship program - regi...
# 310   re: registration fees for cloud practitioner n...
# 318   registration fees for cloud practitioner new b...
# 511   certification course on "internet of vehicles ...
# 628   fwd: ccna academy - introduction to basics of ...
# 629   fwd: ccna academy - introduction to basics of ...
# 664   charusat online degree programs: january 2025 ...
# 666   fwd: depstar updated fees notice dear students...
# 687   last chance to join our scholarship campaign -...
# 803   fwd: mysy renewal/delayed documents submission...
# 925   fwd: c-dac hyderabad invites online applicatio...
# 946   mnc internship program [image: image.png] dear...
# 980   re: notice of fees payment : odd term - ay : 2...
# 1042  fwd: announcement - certificate course titled ...
# 1059  notice of fees payment : odd term - ay : 2024-...
# 1077  re: charusat_fte_depstar_cse_certificate cours...
# 1083  fwd: ec-council academia cost for network defe...
# 1158  charusat_fte_depstar_cse_certificate course in...
# 1221  shepreneur - a stall showcase competition on 7...
# 1255  re: ccna academy - introduction to basics of n...
# 1256  re: supplementary examination - 1_ schedule fo...
# 1259  ccna academy - introduction to basics of netwo...
# 1290  supplementary examination - 1_ schedule for b....
# 1295  ***national level training and internship camp...
# 1315  fwd: fw: call for participation in “poster com...
# 1321  re: examination guidelines dear students, plea...
# 1324  final call to apply training and internship pr...
# 1342  examination guidelines dear students, the fy u...
# 1380  fwd: notice of fees payment dear students, pfa...
# 1469  imp: online training and internship campaign *...
#
#                              sender_email     sender_domain  \
# 26        gaurangpatel.dcs@charusat.ac.in    charusat.ac.in
# 87         onlinecourses@nptel.iitm.ac.in  nptel.iitm.ac.in
# 129          executiveassistant@e.read.ai         e.read.ai
# 158        radhikapatel.it@charusat.ac.in    charusat.ac.in
# 159        nainaparmar.dcs@charusat.ac.in    charusat.ac.in
# 160        nainaparmar.dcs@charusat.ac.in    charusat.ac.in
# 171          executiveassistant@e.read.ai         e.read.ai
# 289       dishapanchal.dcs@charusat.ac.in    charusat.ac.in
# 293                  radhika@krutanic.net      krutanic.net
# 310        sanketsuthar.it@charusat.ac.in    charusat.ac.in
# 318        sanketsuthar.it@charusat.ac.in    charusat.ac.in
# 511   dharmendrachauhan.ec@charusat.ac.in    charusat.ac.in
# 628        nainaparmar.dcs@charusat.ac.in    charusat.ac.in
# 629        nainaparmar.dcs@charusat.ac.in    charusat.ac.in
# 664                    cco@charusat.ac.in    charusat.ac.in
# 666        nainaparmar.dcs@charusat.ac.in    charusat.ac.in
# 687                      lara@codeiox.org       codeiox.org
# 803        radhikapatel.it@charusat.ac.in    charusat.ac.in
# 925        radhikapatel.it@charusat.ac.in    charusat.ac.in
# 946                vamsibitra@codeiox.org       codeiox.org
# 980        radhikapatel.it@charusat.ac.in    charusat.ac.in
# 1042       radhikapatel.it@charusat.ac.in    charusat.ac.in
# 1059       radhikapatel.it@charusat.ac.in    charusat.ac.in
# 1077      kirtimakwana.mba@charusat.ac.in    charusat.ac.in
# 1083       radhikapatel.it@charusat.ac.in    charusat.ac.in
# 1158      kirtimakwana.mba@charusat.ac.in    charusat.ac.in
# 1221       radhikapatel.it@charusat.ac.in    charusat.ac.in
# 1255       radhikapatel.it@charusat.ac.in    charusat.ac.in
# 1256       nainaparmar.dcs@charusat.ac.in    charusat.ac.in
# 1259       radhikapatel.it@charusat.ac.in    charusat.ac.in
# 1290      kirtimakwana.mba@charusat.ac.in    charusat.ac.in
# 1295                   shubham@corizo.org        corizo.org
# 1315       nainaparmar.dcs@charusat.ac.in    charusat.ac.in
# 1321      kirtimakwana.mba@charusat.ac.in    charusat.ac.in
# 1324                321910301031@gitam.in          gitam.in
# 1342      kirtimakwana.mba@charusat.ac.in    charusat.ac.in
# 1380       radhikapatel.it@charusat.ac.in    charusat.ac.in
# 1469                      payal@corizo.in         corizo.in
#
#       contains_submit_word  contains_exam_word  contains_event_word  \
# 26                   False               False                False
# 87                   False               False                False
# 129                   True               False                False
# 158                  False               False                 True
# 159                  False               False                 True
# 160                  False               False                 True
# 171                  False               False                False
# 289                  False                True                False
# 293                   True               False                False
# 310                  False               False                False
# 318                  False               False                False
# 511                  False               False                False
# 628                  False               False                False
# 629                  False               False                False
# 664                  False               False                False
# 666                  False               False                False
# 687                  False               False                False
# 803                   True               False                False
# 925                   True                True                 True
# 946                   True                True                False
# 980                  False               False                False
# 1042                 False               False                False
# 1059                 False               False                False
# 1077                 False               False                False
# 1083                 False                True                False
# 1158                 False               False                False
# 1221                 False               False                 True
# 1255                  True               False                False
# 1256                 False                True                False
# 1259                  True               False                False
# 1290                 False                True                False
# 1295                  True               False                False
# 1315                  True               False                 True
# 1321                  True                True                False
# 1324                  True               False                False
# 1342                  True                True                False
# 1380                 False               False                False
# 1469                  True               False                False
#
#       contains_form_link    deadline_date  contains_deadline label_source  \
# 26                 False                               False
# 87                 False                               False
# 129                False                               False
# 158                False                               False
# 159                False                               False
# 160                False                               False
# 171                False                               False
# 289                False                               False
# 293                False                               False
# 310                False                               False
# 318                False                               False
# 511                False                               False
# 628                False                               False
# 629                False                               False
# 664                False                               False
# 666                False                               False
# 687                False                               False
# 803                False                               False
# 925                False                               False
# 946                False                               False
# 980                False                               False
# 1042               False                               False
# 1059               False                               False
# 1077               False                               False
# 1083               False                               False
# 1158               False                               False
# 1221               False                               False
# 1255               False                               False
# 1256               False                               False
# 1259               False                               False
# 1290               False                               False
# 1295               False                               False
# 1315               False  15 january 2024               True
# 1321               False                               False
# 1324               False                               False
# 1342               False                               False
# 1380               False                               False
# 1469               False                               False
#
#      label_topic label_urgency
# 26
# 87
# 129
# 158
# 159
# 160
# 171
# 289
# 293
# 310
# 318
# 511
# 628
# 629
# 664
# 666
# 687
# 803
# 925
# 946
# 980
# 1042
# 1059
# 1077
# 1083
# 1158
# 1221
# 1255
# 1256
# 1259
# 1290
# 1295
# 1315
# 1321
# 1324
# 1342
# 1380
# 1469

# %%
label_df = df[[
    "from",
    "sender_domain",
    "clean_text",
    "deadline_date",
    "label_source",
    "label_topic",
    "label_urgency"
]]

# %%
label_df.head()
# Out:
#                                                 from     sender_domain  \
# 0  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....   charusat.edu.in
# 1  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....   charusat.edu.in
# 2             NPTEL <onlinecourses@nptel.iitm.ac.in>  nptel.iitm.ac.in
# 3                   Team at Read <support@e.read.ai>         e.read.ai
# 4      Mohini Darji <mohinidarji.dcs@charusat.ac.in>    charusat.ac.in
#
#                                           clean_text deadline_date  \
# 0  request for email data contribution – research...
# 1  re: request for email data contribution – rese...
# 2  nptel newsletter: iit madras code certificate ...
# 3  exclusive education pricing just for you! read...
# 4  reg. submission of sgp- weekly reports dear st...
#
#   label_source label_topic label_urgency
# 0
# 1
# 2
# 3
# 4

# %%
# Find rows where clean_text contains the keyword 'fees' (case-insensitive) and display them
fees_rows = label_df[df['clean_text'].str.contains('fees', case=False, na=False)]
# fees_rows[['clean_text', 'label_topic_model', 'label_topic_rule']]

# %%
fees_rows
# Out:
#                                                    from     sender_domain  \
# 26      Gaurang Patel <gaurangpatel.dcs@charusat.ac.in>    charusat.ac.in
# 87               NPTEL <onlinecourses@nptel.iitm.ac.in>  nptel.iitm.ac.in
# 129       Read Assistant <executiveassistant@e.read.ai>         e.read.ai
# 158      Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 159       Naina Parmar <nainaparmar.dcs@charusat.ac.in>    charusat.ac.in
# 160       Naina Parmar <nainaparmar.dcs@charusat.ac.in>    charusat.ac.in
# 171       Read Assistant <executiveassistant@e.read.ai>         e.read.ai
# 289     Disha Panchal <dishapanchal.dcs@charusat.ac.in>    charusat.ac.in
# 293                                radhika@krutanic.net      krutanic.net
# 310      Sanket Suthar <sanketsuthar.it@charusat.ac.in>    charusat.ac.in
# 318      Sanket Suthar <sanketsuthar.it@charusat.ac.in>    charusat.ac.in
# 511   Dharmendra Chauhan <dharmendrachauhan.ec@charu...    charusat.ac.in
# 628       Naina Parmar <nainaparmar.dcs@charusat.ac.in>    charusat.ac.in
# 629       Naina Parmar <nainaparmar.dcs@charusat.ac.in>    charusat.ac.in
# 664                       CHARUSAT <cco@charusat.ac.in>    charusat.ac.in
# 666       Naina Parmar <nainaparmar.dcs@charusat.ac.in>    charusat.ac.in
# 687                                    lara@codeiox.org       codeiox.org
# 803      Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 925      Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 946                Vamsi bitra <vamsibitra@codeiox.org>       codeiox.org
# 980      Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 1042     Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 1059     Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 1077  "Dr. Kirti Makwana" <kirtimakwana.mba@charusat...    charusat.ac.in
# 1083     Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 1158  "Dr. Kirti Makwana" <kirtimakwana.mba@charusat...    charusat.ac.in
# 1221     Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 1255     Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 1256      Naina Parmar <nainaparmar.dcs@charusat.ac.in>    charusat.ac.in
# 1259     Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 1290  "Dr. Kirti Makwana" <kirtimakwana.mba@charusat...    charusat.ac.in
# 1295                 Shubham Sinha <shubham@corizo.org>        corizo.org
# 1315      Naina Parmar <nainaparmar.dcs@charusat.ac.in>    charusat.ac.in
# 1321  "Dr. Kirti Makwana" <kirtimakwana.mba@charusat...    charusat.ac.in
# 1324         321910301031 gitam <321910301031@gitam.in>          gitam.in
# 1342  "Dr. Kirti Makwana" <kirtimakwana.mba@charusat...    charusat.ac.in
# 1380     Radhika Patel <radhikapatel.it@charusat.ac.in>    charusat.ac.in
# 1469                  Payal Choudhary <payal@corizo.in>         corizo.in
#
#                                              clean_text    deadline_date  \
# 26    semester 5 fee payment schedule - b.tech progr...
# 87    nptel newsletter: june 2025: vol 6: week 2! np...
# 129   weekly kickoff | mon, may 26th | read.ai need ...
# 158   fwd: proposal for students to participate in t...
# 159   fwd: proposal for students to participate in t...
# 160   fwd: proposal for students to participate in t...
# 171   weekly kickoff | mon, may 19th | read.ai need ...
# 289   re: university theory and practical examinatio...
# 293   accenture accredited internship program - regi...
# 310   re: registration fees for cloud practitioner n...
# 318   registration fees for cloud practitioner new b...
# 511   certification course on "internet of vehicles ...
# 628   fwd: ccna academy - introduction to basics of ...
# 629   fwd: ccna academy - introduction to basics of ...
# 664   charusat online degree programs: january 2025 ...
# 666   fwd: depstar updated fees notice dear students...
# 687   last chance to join our scholarship campaign -...
# 803   fwd: mysy renewal/delayed documents submission...
# 925   fwd: c-dac hyderabad invites online applicatio...
# 946   mnc internship program [image: image.png] dear...
# 980   re: notice of fees payment : odd term - ay : 2...
# 1042  fwd: announcement - certificate course titled ...
# 1059  notice of fees payment : odd term - ay : 2024-...
# 1077  re: charusat_fte_depstar_cse_certificate cours...
# 1083  fwd: ec-council academia cost for network defe...
# 1158  charusat_fte_depstar_cse_certificate course in...
# 1221  shepreneur - a stall showcase competition on 7...
# 1255  re: ccna academy - introduction to basics of n...
# 1256  re: supplementary examination - 1_ schedule fo...
# 1259  ccna academy - introduction to basics of netwo...
# 1290  supplementary examination - 1_ schedule for b....
# 1295  ***national level training and internship camp...
# 1315  fwd: fw: call for participation in “poster com...  15 january 2024
# 1321  re: examination guidelines dear students, plea...
# 1324  final call to apply training and internship pr...
# 1342  examination guidelines dear students, the fy u...
# 1380  fwd: notice of fees payment dear students, pfa...
# 1469  imp: online training and internship campaign *...
#
#      label_source label_topic label_urgency
# 26
# 87
# 129
# 158
# 159
# 160
# 171
# 289
# 293
# 310
# 318
# 511
# 628
# 629
# 664
# 666
# 687
# 803
# 925
# 946
# 980
# 1042
# 1059
# 1077
# 1083
# 1158
# 1221
# 1255
# 1256
# 1259
# 1290
# 1295
# 1315
# 1321
# 1324
# 1342
# 1380
# 1469

# %%
label_df.to_csv("unlabeled_dataset.csv",index=False)

# %%
label_df = interactive_level1_labeler(label_df)
label_df.to_csv("labeled_level1.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 label_df = interactive_level1_labeler(label_df)
#       2 label_df.to_csv("labeled_level1.csv", index=False)
#
# NameError: name 'interactive_level1_labeler' is not defined
