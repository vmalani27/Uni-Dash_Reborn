# %%
import pandas as pd

# %%
df=pd.read_csv(r"level2_llm_runs\run_20260206_045218\level2_labeled.csv")

# %%
df.head()
# Out:
#                              sender_email           sender_domain  \
# 0  recommendations@discover.pinterest.com  discover.pinterest.com
# 1          nainaparmar.dcs@charusat.ac.in          charusat.ac.in
# 2          onlinecourses@nptel.iitm.ac.in        nptel.iitm.ac.in
# 3         netacademail@external.cisco.com      external.cisco.com
# 4            no-reply@accounts.google.com     accounts.google.com
#
#                                              subject  \
# 0                           Form Design for 23DCS023
# 1  Fwd: Start Up Accelerator Program(SAP) initiat...
# 2        Programming in Java - Week 09 Feedback Form
# 3            NetAcad Student Newsletter – April 2025
# 4                                     Security alert
#
#                                           clean_text  \
# 0  form design for 23dcs023 to view this content ...
# 1  fwd: start up accelerator program(sap) initiat...
# 2    programming in java - week 09 feedback form nan
# ...

# %%
# show distribution of labels (counts + percentages) and plot a horizontal bar chart
label_series = df['label_topic'].fillna('Unlabeled')
counts = label_series.value_counts()
percents = label_series.value_counts(normalize=True).mul(100).round(2)
dist = pd.concat([counts, percents], axis=1, keys=['count', 'percent'])
print(dist)

import matplotlib.pyplot as plt

counts_sorted = counts.sort_values(ascending=True)
plt.figure(figsize=(8, 5))
ax = counts_sorted.plot(kind='barh', color='C0')
plt.xlabel('Count')
plt.title('Label distribution')
# annotate counts on bars
for i, (idx, v) in enumerate(counts_sorted.items()):
    ax.text(v + max(counts_sorted) * 0.01, i, f"{v} ({dist.loc[idx,'percent']}%)", va='center')
plt.tight_layout()
plt.show()
# Out:
#                                       count  percent
# label_topic
# Internship / Placement Opportunities     32    21.33
# Events / Hackathons                      32    21.33
# Exam Notifications                       22    14.67
# Certification / Courses                  17    11.33
# General Information / Misc               17    11.33
# Assignment or Submission                 13     8.67
# Timetable / Schedule Update              10     6.67
# Important Announcements                   4     2.67
# Administrative / Fees / Counselling       3     2.00

# %%
df["label_urgency"].value_counts()
# Out:
# label_urgency
# High        64
# Medium      43
# Low         31
# Critical     1
# Name: count, dtype: int64

# %%
pd.crosstab(df["label_source"], df["label_topic"])
# Out:
# label_topic                 Administrative / Fees / Counselling  \
# label_source
# External / Misc                                               2
# External Academic Platform                                    0
# Institutional Sender                                          1
# Student / Peer                                                0
#
# label_topic                 Assignment or Submission  Certification / Courses  \
# label_source
# External / Misc                                    0                        7
# External Academic Platform                         9                        4
# Institutional Sender                               4                        5
# Student / Peer                                     0                        1
#
# label_topic                 Events / Hackathons  Exam Notifications  \
# label_source
# External / Misc                               4                   0
# External Academic Platform                    0                   8
# ...

# %%
df[df["label_topic"] == "Assignment or Submission"][
    ["label_source", "subject", "summary"]
].sample(10, random_state=42)
# Out:
#                    label_source  \
# 99   External Academic Platform
# 87         Institutional Sender
# 2    External Academic Platform
# 70   External Academic Platform
# 23   External Academic Platform
# 11         Institutional Sender
# 10   External Academic Platform
# 139  External Academic Platform
# 20         Institutional Sender
# 33         Institutional Sender
#
#                                                subject  \
# 99   Week 1 Feedback Form : Design and analysis of ...
# 87    Fwd: Regarding Sheet-2 Preparation, ME145 EOE-EG
# 2          Programming in Java - Week 09 Feedback Form
# 70   Programming in Java  - Assignment-01 Solution ...
# 23         Programming in Java - Week 03 Feedback Form
# 11   Fwd: Reg. CCP Submission Practical File and Ha...
# 10   Programming in Java - Assignment-05 Solution R...
# 139  Design and Analysis of Algorithms : Week 1 con...
# 20                        Submission of IoT Components
# ...

# %%
df[df["label_urgency"].isin(["Critical", "High"])][
    ["label_topic", "subject", "summary"]
].sample(15, random_state=42)
# Out:
#                               label_topic  \
# 119                   Events / Hackathons
# 140               Certification / Courses
# 8             Timetable / Schedule Update
# 101           Timetable / Schedule Update
# 18                     Exam Notifications
# 141  Internship / Placement Opportunities
# 47                    Events / Hackathons
# 35                Important Announcements
# 148  Internship / Placement Opportunities
# 72                    Events / Hackathons
# 81                     Exam Notifications
# 25   Internship / Placement Opportunities
# 93                     Exam Notifications
# 39   Internship / Placement Opportunities
# 82                     Exam Notifications
#
#                                                subject  \
# 119  Fwd: Hurry up - Deadline approaching for Smart...
# 140  ⚠️ FINAL 24 HOURS: A Decision That Could Chang...
# 8                                                  NaN
# 101                      Regarding SGP Internal Review
# ...

# %%
df[
    (df["label_source"] == "Institutional Sender") &
    (df["label_topic"] == "Administrative / Fees / Counselling")
][["subject", "summary"]].head(10)
# Out:
#                                               subject  \
# 56  Fwd: Nptel Local Chapter : Last chance to chan...
#
#                                               summary
# 56  Last chance to update share info for NPTEL exa...

# %%
df.sample(15, random_state=0)[["summary", "label_topic", "label_urgency"]]
# Out:
#                                                summary  \
# 114  Second Round of SSIP 2.0: Submit Project Detai...
# 62   Register for NIDAR: India’s Largest National D...
# 33   Lab manual and journal due date, Quiz 2 for En...
# 107  Register for Bolt's $1M Hackathon starting May 30
# 7    Confirmation of rescheduled DAA internal exam ...
# 100  Attend Live Webinar on Swayam Plus on May 13, ...
# 40   IEEE Student Membership Half-Yearly Offer Avai...
# 86      Important update on exam format for March 2025
# 76           Event participation application approved.
# 71   Please review the attached schedule for BTECH(...
# 134  Submit applications for project work opportuni...
# 51   Free Bolt Pro and Builder Pack for Hackathon P...
# 73   Google Cloud Next: AI and Cloud Innovation Upd...
# 54   Reminder for design and analysis of algorithms...
# 63   Register for StackHack 1.0 to win prizes and n...
#
#                               label_topic label_urgency
# ...
