# %%
import pandas as pd

# %%
df=pd.read_csv("level2_model_ready.csv")

# %%
df.head()
# Out:
#                                                 from     sender_domain  \
# 0  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....   charusat.edu.in
# 1  23DCS023 JAMES DHANDHUKIYA <23dcs023@charusat....   charusat.edu.in
# 2             NPTEL <onlinecourses@nptel.iitm.ac.in>  nptel.iitm.ac.in
# 3                   Team at Read <support@e.read.ai>         e.read.ai
# 4      Mohini Darji <mohinidarji.dcs@charusat.ac.in>    charusat.ac.in
#
#                                           clean_text deadline_date  \
# 0  request for email data contribution – research...           NaN
# 1  re: request for email data contribution – rese...           NaN
# 2  nptel newsletter: iit madras code certificate ...           NaN
# 3  exclusive education pricing just for you! read...           NaN
# 4  reg. submission of sgp- weekly reports dear st...           NaN
#
#                label_source  label_topic  label_urgency  \
# 0            Student / Club          NaN            NaN
# ...

# %%
# show distribution of labels (counts + percentages) and plot a horizontal bar chart
label_series = df['label_topic_model'].fillna('Unlabeled')
counts = label_series.value_counts()
percents = label_series.value_counts(normalize=True).mul(100).round(2)
dist = pd.concat([counts, percents], axis=1, keys=['count', 'percent'])
print(dist)

import matplotlib.pyplot as plt

counts_sorted = counts.sort_values(ascending=True)
plt.figure(figsize=(8, 5))
ax = counts_sorted.plot(kind='barh', color='C0')
plt.xlabel('Count')
plt.title('Label distribution')
# annotate counts on bars
for i, (idx, v) in enumerate(counts_sorted.items()):
    ax.text(v + max(counts_sorted) * 0.01, i, f"{v} ({dist.loc[idx,'percent']}%)", va='center')
plt.tight_layout()
plt.show()
# Out:
#                                       count  percent
# label_topic_model
# Important Announcements                 682    44.46
# Certification / Courses                 324    21.12
# Events / Hackathons                     207    13.49
# Assignment or Submission                134     8.74
# General Information / Misc               91     5.93
# Internship / Placement Opportunities     43     2.80
# Timetable / Schedule Update              27     1.76
# Exam Notifications                       26     1.69

# %%
# For every unique label_source, return 5 emails with their clean_text
unique_labels = df['label_topic_model'].unique()

for label in unique_labels:
    print(f"Label: {label}")
    subset = df[df['label_topic_rule'] == label].head(5)
    for idx, row in subset.iterrows():
        print(f"Email {idx}: {row['clean_text']}")
    print("\n---\n")
# Out:
# Label: Important Announcements
# ...

# %%
# For every unique label_source, return 5 emails with their clean_text
unique_labels = df['label_topic'].unique()

for label in unique_labels:
    print(f"Label: {label}")
    subset = df[df['label_topic'] == label].head(5)
    for idx, row in subset.iterrows():
        print(f"Email {idx}: {row['clean_text']}")
    print("\n---\n")
# Out:
# Label: Assignment or Submission
# ...

# %%
# Find rows where clean_text contains the keyword 'fees' (case-insensitive) and display them
fees_rows = df[df['clean_text'].str.contains('fees', case=False, na=False)]
fees_rows[['clean_text', 'label_topic_model', 'label_topic_rule']]
# Out:
#                                              clean_text  \
# 26    semester 5 fee payment schedule - b.tech progr...
# 87    nptel newsletter: june 2025: vol 6: week 2! np...
# 129   weekly kickoff | mon, may 26th | read.ai need ...
# 158   fwd: proposal for students to participate in t...
# 159   fwd: proposal for students to participate in t...
# 160   fwd: proposal for students to participate in t...
# 171   weekly kickoff | mon, may 19th | read.ai need ...
# 289   re: university theory and practical examinatio...
# 293   accenture accredited internship program - regi...
# 310   re: registration fees for cloud practitioner n...
# 318   registration fees for cloud practitioner new b...
# 511   certification course on "internet of vehicles ...
# 627   fwd: ccna academy - introduction to basics of ...
# 628   fwd: ccna academy - introduction to basics of ...
# 663   charusat online degree programs: january 2025 ...
# 665   fwd: depstar updated fees notice dear students...
# ...
